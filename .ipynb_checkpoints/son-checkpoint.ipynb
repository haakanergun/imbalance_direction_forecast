# %% [markdown]
# # Dengesizlik Yönü Tahmini
#
# Enerji sektöründe dengesizlik yönü tahmini, enerji arzı ve talebi arasındaki farkı önceden belirlemek için kullanılan bir yöntemdir. Enerji arzı ve talebi arasındaki dengesizlik, elektrik şebekesinin istikrarını ve güvenliğini etkileyebilir. Bu nedenle, dengesizlik yönünü doğru bir şekilde tahmin etmek, enerji üreticileri, tüketicileri ve iletim sistem operatörleri için önemlidir.
#
# ![Bing AI ile oluşturulmuş enerji üretim merkezi](attachment:image.png)
#
# Bu çalışmada, zaman serisi verilerini kullanarak enerji dengesizlik yönünü tahmin etmek için PyCaret kütüphanesini kullanarak farklı sınıflandırma modelleri oluşturduk. Modeller, enerji talebi, hava durumu ve özel günler gibi dışsal faktörlerin etkisini dikkate alan bir dizi özellik üzerinde eğitilmiştir. Özellik mühendisliği ve veri ön işleme adımları da bu süreçte gerçekleştirilmiştir.

# %% [markdown]
# # 1. Veri Toplama

# %% [markdown]
# ## 1.1. Kütüphanelerin içe Aktarılması

# %%
import requests
import pandas as pd
from datetime import timedelta
from sklearn.metrics import accuracy_score
import numpy as np
from datetime import datetime
import datetime as dt
import json

import matplotlib.pyplot as plt
import seaborn as sns

from bs4 import BeautifulSoup

# %% [markdown]
# ## 1.2. EPİAŞ'tan Veri Çekme
#
# EPİAŞ API servisi kullanılarak belirtilen tarih aralığındaki verilerin çekilmesi.

# %%
url = "https://seffaflik.epias.com.tr/transparency/service/market/smp?endDate=2022-12-31&startDate=2022-01-01"
response = requests.get(url)
data = response.json()

# %% [markdown]
# ## 1.3. Veriyi Pandas DataFrame'e Dönüştürme
#
# Çeşitli ön işlemelerin yapılması için verinin pandas DataFrame formatına dönüştürülmesi.

# %%
smp_list = data['body']["smpList"]
df = pd.DataFrame(smp_list)
df["date"] = pd.to_datetime(df["date"], format="%Y-%m-%d %H:%M")

# %%
df.head()
# Out:
#                        date   price smpDirection  smpDirectionId  \
# 0 2022-01-01 00:00:00+03:00  525.00          YAT               3
# 1 2022-01-01 01:00:00+03:00  848.01          YAL               1
# 2 2022-01-01 02:00:00+03:00  990.00          YAL               1
# 3 2022-01-01 03:00:00+03:00  500.00          YAT               3
# 4 2022-01-01 04:00:00+03:00  500.00          YAT               3
#
#                        nextHour
# 0  2022-01-01T01:00:00.000+0300
# 1  2022-01-01T02:00:00.000+0300
# 2  2022-01-01T03:00:00.000+0300
# 3  2022-01-01T04:00:00.000+0300
# 4  2022-01-01T05:00:00.000+0300

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            8760 non-null   datetime64[ns, pytz.FixedOffset(180)]
#  1   price           8760 non-null   float64
#  2   smpDirection    8760 non-null   object
#  3   smpDirectionId  8760 non-null   int64
#  4   nextHour        8760 non-null   object
# dtypes: datetime64[ns, pytz.FixedOffset(180)](1), float64(1), int64(1), object(2)
# memory usage: 342.3+ KB

# %%
df.describe()
# Out:
#              price  smpDirectionId
# count  8760.000000     8760.000000
# mean   2548.647017        1.389269
# std    1269.177221        0.779093
# min       0.000000        1.000000
# 25%    1524.000000        1.000000
# 50%    2450.000000        1.000000
# 75%    3503.000000        1.000000
# max    4800.000000        3.000000

# %% [markdown]
# Price değişkeni normal dağılıyor gibi görülmektedir

# %%
df.isna().sum()
# Out:
# date              0
# price             0
# smpDirection      0
# smpDirectionId    0
# nextHour          0
# dtype: int64

# %%
# 3. Boxplot Grafiği
plt.figure(figsize=(8, 6))
sns.boxplot(y='price', data=df)
plt.ylabel('Fiyat')
plt.title('Fiyat Boxplot Grafiği')
plt.show()


# Dengesizlik Yönü Dağılımı
plt.figure(figsize=(6, 6))
sns.countplot(x="smpDirection", data=df)
plt.title("Dengesizlik Yönü Dağılımı")
plt.xlabel("Dengesizlik Yönü")
plt.ylabel("Sayım")
plt.show()

# %% [markdown]
# ##### Fiyat Dağılımı
#
# Fiyatların boxplot grafiği, fiyatların dağılımının normal olduğunu göstermektedir. Ayrıca aykırı değerlerin olmadığını da görebiliyoruz.
# ##### Dengesizlik Yönü Dağılımı
#
# Dengesizlik yönü dağılımı grafiği, YAL dengesizlik yönünün en yaygın olduğunu, YAT'ın daha az yaygın olduğunu ve DNG sınıfının ise çok nadir olduğunu göstermektedir.

# %%
# 4. Aylık Ortalama Fiyat Grafiği
df['month'] = df['date'].dt.month
monthly_average_prices = df.groupby('month')['price'].mean()

plt.figure(figsize=(10, 6))
plt.bar(monthly_average_prices.index, monthly_average_prices.values)
plt.xlabel('Ay')
plt.ylabel('Ortalama Fiyat')
plt.title('Aylık Ortalama Fiyat Grafiği')
plt.show()

# %% [markdown]
# 2022 yılında aylık bazda zamana göre fiyatların ortalamasında artış olduğunu söyleyebiliriz.

# %%
# 5. Haftalık ve Günlük Fiyat Değişimleri
df['weekday'] = df['date'].dt.weekday
df['hour'] = df['date'].dt.hour
weekly_avg_prices = df.groupby(['weekday', 'hour'])['price'].mean().unstack()

plt.figure(figsize=(12, 6))
sns.heatmap(weekly_avg_prices, cmap='viridis', annot=False, fmt='.2f')
plt.xlabel('Saat')
plt.ylabel('Haftanın Günü')
plt.title('Haftalık Bazda Günlük Fiyat Değişimleri')
plt.show()

# %% [markdown]
# Yukarıdaki sıcaklık grafiğine göre haftanın günleri bazında gün doğumundan sonra 8-9-10-11 saatlerinde bir fiyat artışı gözlenmektedir. 12 ve 13te düşüş ve sonra gece saatlerine kadar bir fiyat artışı gözlemlenmiştir

# %%
# 6. Isı Haritası (örnek olarak aylık ve saatlik veriler için)
monthly_hourly_avg_prices = df.groupby(['month', 'hour'])['price'].mean().unstack()

plt.figure(figsize=(12, 6))
sns.heatmap(monthly_hourly_avg_prices, cmap='viridis', annot=False, fmt='.2f')
plt.xlabel('Saat')
plt.ylabel('Ay')
plt.title('Aylık ve Saatlik Fiyat Değişimleri')
plt.show()

# %% [markdown]
# Fiyatların en yüksek değerine ulaştığı zamanı 9,10,11,12. aylar olarak söyleyebiliriz.

# %% [markdown]
# # 2. Sezgisel Kuralın Performansının Değerlendirilmesi
#
# # 2.1. Sezgisel Kural Uygulanması (T-3)
#
# T-3 sezgisel kuralı, elektrik piyasalarında kullanılan bir kuraldır ve dengesizlik tahminlerinde kullanılır. Elektrik piyasaları, arz ve talep dengesini sürekli olarak sağlamak zorundadır, çünkü elektrik enerjisi anında tüketilmesi gereken ve kolayca depolanamayan bir üründür. Dengesizlik, tüketim ve üretim arasındaki farkın olması durumudur ve bu farklar, enerji sistemini istikrarsız hale getirebilir.
#
# T-3 sezgisel kuralı, şu anki saat (T) ile 3 saat önceki saat (T-3) arasındaki dengesizlik yönünün (arz fazlalığı veya talep fazlalığı) benzer olduğunu varsayar. Bu kural, özellikle gün içi elektrik piyasasında, dengesizlik yönetimi ve dengesizlik fiyatlarının tahmin edilmesinde kullanılır. Mantığı, geçmiş saatlerdeki dengesizlik yönünün, mevcut saatteki dengesizlik yönü üzerinde belirleyici bir etkisi olduğunu düşünmektir.
#
# Aşağıda, belirtilen kuralın performansı ölçülmüş ve yorumlanmıştır.

# %%
df["predicted_smp_direction"] = df["smpDirection"].shift(3)
df = df.dropna() # Lag alındıktan sonra ilk üç veri hesaplanamayacağı için ve aynı zamanda metrik sonucunu etkileyeceği için düşürülmüştür.

# %% [markdown]
# ## 2.2. Performans Metriklerinin Hesaplanması
#
# Sezgisel kuralın performansının hesaplanması için doğruluk (accuracy) metriği kullanılmıştır.

# %%
accuracy = (df["smpDirection"] == df["predicted_smp_direction"]).mean()
print(f"Sezgisel kuralın performansı: {accuracy:.2%}")
# Out:
# Sezgisel kuralın performansı: 79.76%

# %% [markdown]
# ### 2.3. Saatlik ve Aylık Performans Analizi
#
# Saatlik ve aylık performansı analiz etmek için, saat ve ay sütunları oluşturulmuş ve doğrulukları hesaplanmıştır.

# %%
df["hour"] = df["date"].dt.hour
df["month"] = df["date"].dt.month

hourly_accuracy = df.groupby("hour").apply(lambda x: (x["smpDirection"] == x["predicted_smp_direction"]).mean())
monthly_hourly_accuracy = df.groupby(["month", "hour"]).apply(lambda x: (x["smpDirection"] == x["predicted_smp_direction"]).mean())

print("Saatlik performans:")
print(hourly_accuracy)

print("\nAylık bazda saatlik performans:")
print(monthly_hourly_accuracy.unstack())
# Out:
# Saatlik performans:
# hour
# 0     0.788462
# 1     0.760989
# 2     0.752747
# 3     0.767123
# 4     0.813699
# 5     0.830137
# 6     0.742466
# 7     0.739726
# 8     0.761644
# 9     0.736986
# 10    0.794521
# 11    0.832877
# 12    0.772603
# 13    0.810959
# 14    0.860274
# 15    0.830137
# 16    0.800000
# 17    0.865753
# 18    0.827397
# 19    0.819178
# 20    0.849315
# 21    0.830137
# 22    0.775342
# 23    0.780822
# dtype: float64
#
# Aylık bazda saatlik performans:
# hour         0         1         2         3         4         5         6   \
# month
# 1      0.933333  0.900000  0.900000  0.774194  0.741935  0.774194  0.709677
# 2      0.821429  0.607143  0.785714  0.785714  0.892857  0.857143  0.714286
# 3      0.838710  0.806452  0.774194  0.903226  0.967742  0.935484  0.870968
# 4      0.800000  0.800000  0.700000  0.866667  0.800000  0.800000  0.533333
# 5      0.677419  0.548387  0.612903  0.612903  0.903226  0.838710  0.838710
# 6      0.766667  0.833333  0.933333  0.766667  0.800000  0.800000  0.700000
# 7      0.838710  0.806452  0.741935  0.774194  0.838710  0.838710  0.612903
# 8      0.870968  0.903226  0.806452  0.870968  0.870968  0.903226  0.870968
# 9      0.866667  0.800000  0.700000  0.700000  0.666667  0.766667  0.766667
# 10     0.677419  0.677419  0.645161  0.645161  0.774194  0.774194  0.806452
# 11     0.700000  0.700000  0.733333  0.833333  0.800000  0.866667  0.700000
# 12     0.677419  0.741935  0.709677  0.677419  0.709677  0.806452  0.774194
#
# hour         7         8         9   ...        14        15        16  \
# month                                ...
# 1      0.741935  0.741935  0.838710  ...  0.903226  0.838710  0.774194
# 2      0.750000  0.821429  1.000000  ...  0.785714  0.857143  0.892857
# 3      0.870968  0.870968  0.903226  ...  0.935484  0.967742  0.903226
# 4      0.600000  0.766667  0.466667  ...  0.833333  0.833333  0.600000
# 5      0.741935  0.677419  0.612903  ...  0.838710  0.870968  0.838710
# 6      0.666667  0.733333  0.600000  ...  0.933333  0.866667  0.866667
# 7      0.838710  0.741935  0.645161  ...  0.806452  0.677419  0.806452
# 8      0.870968  0.870968  0.741935  ...  0.935484  0.967742  0.903226
# 9      0.733333  0.800000  0.800000  ...  0.800000  0.733333  0.766667
# 10     0.741935  0.774194  0.838710  ...  0.838710  0.677419  0.709677
# 11     0.600000  0.666667  0.700000  ...  0.833333  0.766667  0.766667
# 12     0.709677  0.677419  0.709677  ...  0.870968  0.903226  0.774194
#
# hour         17        18        19        20        21        22        23
# month
# 1      0.870968  0.838710  0.774194  0.806452  0.774194  0.774194  0.806452
# 2      0.892857  0.785714  0.821429  0.821429  0.714286  0.678571  0.785714
# 3      0.935484  0.935484  0.935484  0.935484  0.967742  0.903226  0.870968
# 4      0.766667  0.666667  0.666667  0.866667  0.900000  0.900000  0.833333
# 5      0.806452  0.838710  0.774194  0.806452  0.838710  0.838710  0.806452
# 6      0.900000  0.866667  0.833333  0.800000  0.800000  0.800000  0.800000
# 7      0.806452  0.838710  0.838710  0.935484  0.903226  0.838710  0.903226
# 8      0.903226  0.838710  0.903226  0.903226  0.935484  0.870968  0.774194
# 9      0.833333  0.866667  0.866667  0.900000  0.866667  0.766667  0.800000
# 10     0.903226  0.741935  0.903226  0.935484  0.806452  0.645161  0.806452
# 11     0.933333  0.866667  0.633333  0.633333  0.600000  0.566667  0.600000
# 12     0.838710  0.838710  0.870968  0.838710  0.838710  0.709677  0.580645
#
# [12 rows x 24 columns]

# %% [markdown]
# - Sezgisel kuralın genel performansı: %79.76
# - Özellikle saatlik ve aylık performans analizlerinde, sezgisel kuralın bazı saatlerde ve aylarda daha iyi performans gösterdiği görülüyor. Bu, kuralın belirli durumlar için daha uygun olduğunu düşündürebilir.

# %%
# Saatlik performans
plt.figure(figsize=(10, 6))
hourly_accuracy.plot(kind="bar")
plt.title("Saatlik Performans")
plt.xlabel("Saat")
plt.ylabel("Doğruluk")
plt.ylim(0, 1)
plt.show()

# Aylık bazda saatlik performans
plt.figure(figsize=(15, 8))
sns.heatmap(monthly_hourly_accuracy.unstack(), annot=True, fmt=".2f", cmap="coolwarm", cbar_kws={"label": "Doğruluk"})
plt.title("Aylık Bazda Saatlik Performans")
plt.xlabel("Saat")
plt.ylabel("Ay")
plt.show()

# %% [markdown]
# ##### Saatlik Performans
#
# Sezgisel kuralın saatlik performansı grafiği, kuralın bazı saatlerde daha iyi performans gösterdiğini göstermektedir. Özellikle, saat 17'de en yüksek doğruluk oranına (%86.6) ulaşılırken, saat 9'da en düşük doğruluk oranıyla (%73.7) karşılaşılmaktadır. Bu, enerji talebinin ve arzının belirli saatlerde daha öngörülebilir olduğunu ve kuralın bu saatlerde daha başarılı olduğunu gösteriyor olabilir
#
# ##### Aylık Bazda Saatlik Performansın
#
# Aylık bazda saatlik performansın ısı haritası, sezgisel kuralın belirli aylarda ve saatlerde nasıl performans gösterdiğini göstermektedir. Özellikle, 2. ayın saat 9'unda %100 doğruluk elde edilirken, 3. ayda ortalama olarak çok iyi tahminler yapılmış ve neredeyse hepsi %90 üzerinde doğruluk sağlanmıştır. Bununla birlikte, 4. ay, sezgisel kuralın en kötü performans gösterdiği dönemdir; özellikle saat 9'da %47 doğruluk elde edilmiştir. Bu bulgular, enerji talebi ve arzının belirli aylar ve saatlerde daha öngörülebilir olduğunu gösteriyor olabilir ve bu durum, sezgisel kuralın başarısını etkileyebilir.

# %% [markdown]
# # 3. İleri Dönemler İçin Dengesizlik Yönü Tahmini
#
# ## 3.1. EPİAŞ'tan "DGP Talimat REST Servisi" Verilerini Çekme
#
# EPİAŞ'tan "DGP Talimat REST SERVİSİ" verilerini çekmek için, gerekli parametreler ve request URL'si belirlenmiş.
#
# #### Parametreler
#
# - Bu problem için start_date 2018-01-01, end_date 2022-12-31 olarak belirlenmiştir.
# - Model, sezgisel kural ile kıyaslanacağı için 2022 yılı test veri kümesi olacaktır.
# - 2021 validasyon veri kümesi olacak ve 2021den önceki veri eğitim veri seti olacaktır.
# - %60 eğitim, %20 validasyon ve %20 test.

# %%
base_url = "https://seffaflik.epias.com.tr/transparency/service/market/bpm-order-summary"
start_date = "2018-01-01"
end_date = "2022-12-31"

params = {
    "startDate": start_date,
    "endDate": end_date
}

dgp_response = requests.get(base_url, params=params)
dgp_data = dgp_response.json()

# %% [markdown]
# ## 3.2. Veriyi Pandas DataFrame'e Dönüştürme
#
# Çeşitli ön işlemelerin yapılması için veri pandas DataFrame'e dönüştürülmüştür

# %%
# 'bpmOrderSummaryList' anahtarını kullanarak ilgili bilgilerin elde edilmesi
dgp_list = dgp_data['body']["bpmOrderSummaryList"]

# Tüm saatler için ilgili verileri içeren bir DataFrame oluşturulması
hour_data = []

for hour_info in dgp_list:
    hour_info["tarih"] = pd.to_datetime(hour_info["date"], format="%Y-%m-%dT%H:%M:%S.%f%z")
    hour_data.append(hour_info)

# Tüm saatlerin verilerini içeren tek bir DataFrame oluşturulması
dgp_df = pd.DataFrame(hour_data)

# %% [markdown]
# ## 3.3. Özellik Çıkarımı

# %% [markdown]
# ### 3.3.1. Covid Flag
#
# TimeSeries problemlerinde Covid-19 dönemine Flag atamak doğru bir yaklaşım olabilir.

# %%
dgp_df["covid_flag"] = np.where((dgp_df["date"] >= "2020-03-11") & (dgp_df["date"] <= "2022-05-31"), 1, 0)

# %% [markdown]
# ### 3.5.3 Tarihsel Özellik Çıkarımı

# %%
dgp_df['Year'] = dgp_df['tarih'].dt.year
dgp_df['Month'] = dgp_df['tarih'].dt.strftime('%B')
dgp_df['Day'] = dgp_df['tarih'].dt.day
dgp_df['Day of Week'] = dgp_df['tarih'].dt.strftime('%A')
dgp_df['Day of Year'] = dgp_df['tarih'].dt.day_of_year
dgp_df['Series'] = np.arange(0,len(dgp_df))+1
dgp_df['decmonth'] = dgp_df['tarih'].dt.month
dgp_df["hour"] = dgp_df["tarih"].dt.hour
# Gün başlangıçlarının belirlenmesi
dgp_df['day_start'] = dgp_df['hour'] == 0

# %% [markdown]
# ### 3.5.2 net Değişkeninden Özellik Çıkarımları
#
# net değişkeninin günlük bazda kümülatif ortalaması ve bir saatten 180 saate (yaklaşık bir hafta) lag'ının alınması doğru bir yaklaşım olabilir.

# %%
# Kümülatif ortalama sütununun tanımlanması
dgp_df['cumulative_avg'] = 0.0

# Günlerin başlangıçlarının alınması
day_starts = dgp_df[dgp_df['day_start']].index.tolist()

# Her günün kümülatif ortalamasını hesaplama
for i in range(len(day_starts)):
    start = day_starts[i]
    if i < len(day_starts) - 1:
        end = day_starts[i + 1]
    else:
        end = len(dgp_df)
    cum_sum = 0
    count = 0
    for j in range(start, end):
        cum_sum += dgp_df.loc[j, 'net']
        count += 1
        dgp_df.loc[j, 'cumulative_avg'] = cum_sum / count

for lag in range(1, 180):
    dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# Out:
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\2580420016.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df[f"net_lag{lag}"] = dgp_df["net"].shift(lag)

# %% [markdown]
# ### 3.5.3 Bağımlı Değişkenin Oluşturulması
#
# Mevcut zamandan 3 saat sonraki dengesizlik yönü tahmin edileceği için, bütün veriyi 3 periyot laglamak için bağımlı değişkeni -3 saat ileri atıyoruz.

# %%
#Geçmiş saatlerdeki verilere dayalı özellikler eklemek için 'shift' fonksiyonu kullanarak bağımlı değişkeni tanımla

dgp_df["target_direction"] = dgp_df["direction"].shift(-3)
# Out:
# C:\Users\Hakan\AppData\Local\Temp\ipykernel_23208\3698567279.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   dgp_df["target_direction"] = dgp_df["direction"].shift(-3)

# %%
dgp_df = dgp_df.dropna()

# %% [markdown]
# ## 3.4. Modelin Eğitimi ve Tahminlerin Yapılması

# %% [markdown]
# #### 3.4.1 PyCaret
#
# PyCaret, Python’da makine öğrenimi iş akışlarını otomatikleştiren açık kaynaklı, düşük kodlu bir makine öğrenimi kütüphanesidir. PyCaret ile makine öğrenimi modellerini eğitmek, değerlendirmek, karşılaştırmak, optimize etmek ve dağıtmak için yüzlerce satır kod yerine sadece birkaç satır kod yazılabilir.

# %% [markdown]
# PyCaret’in avantajları şunlardır:
#
# - Hızlı ve kolay kurulum. PyCaret pip veya conda ile yüklenebilir veya Docker ile çalıştırılabilir.
#
# - Modüler ve tutarlı tasarım. PyCaret, belirli makine öğrenimi görevlerini kapsayan modüllerden oluşur. Her modüldeki fonksiyonlar birbiriyle uyumludur ve diğer modüllerle de çalışabilir.
#
# - Veri ön işleme ve özellik mühendisliği desteği. PyCaret, verileri ölçeklendirmek, dönüştürmek, eksik değerleri doldurmak, kategorik değişkenleri kodlamak, aykırı değerleri tespit etmek ve gidermek gibi birçok veri ön işleme işlevi sunar. Ayrıca, verilerden yeni özellikler türetmek için PCA, RFE ve diğer yöntemleri de kullanabilir.
#
# - Çoklu model eğitimi ve karşılaştırma. PyCaret, bir veri seti üzerinde birden fazla modelin otomatik olarak eğitilmesine ve performanslarının çeşitli metriklerle karşılaştırılmasına olanak tanır. Bu şekilde en uygun modeli seçilebilir.
# - Model optimizasyonu ve seçimi. PyCaret, model hiperparametrelerini optimize etmek için ızgara araması (GridSearch) veya rastgele arama (RandomSearch) gibi yöntemleri kullanabilir. Ayrıca, model seçimi için çapraz doğrulama veya katmanlı doğrulama gibi teknikleri de uygulayabilirsiniz1.
# - Model açıklaması ve yorumlanması. PyCaret, eğitilmiş modellerin nasıl çalıştığını anlamak için çeşitli araçlar sunar. Örneğin, ROC eğrisi, hassasiyet-duyarlılık eğrisi, karışıklık matrisi gibi performans göstergelerini gösterebilir. Ayrıca, SHAP gibi kütüphaneleri kullanarak modelin tahminlerini açıklayabilir veya etkileşimli olarak görselleştirilebilir.
# - Model dağıtımı ve izlenmesi. PyCaret, eğitilmiş modellerin REST API olarak dağıtılmasına veya basit bir web uygulaması oluşturulmasına olanak tanır. Ayrıca, model AWS veya Azure gibi bulut platformlara dağıtılabilir veya MLflow gibi araçlarla izlenebilir.

# %%
from pycaret.classification import *

# %%
valid_data = dgp_df[(dgp_df['date']<'2022') & (dgp_df['date']>'2021')]
test_data = dgp_df[(dgp_df['date']>'2022')]
train_data = dgp_df[(dgp_df['date']<'2021')]

# %% [markdown]
# 3.1 başlığında belirtildiği gibi veriseti %60 eğitim, %20 validasyon ve %20 test oalrak zamana göre bölünmüştür. Buradaki amaç zaman serisi olduğu için bu bütünlüğü bozmamaya çalışmaktır. (Verisetine random sampling uygulanarak bölünme uygulandığında modelin başarısı daha da düşük çıkmıştır).

# %%
clf = setup(data=train_data,
            test_data=valid_data,
            data_split_shuffle=False,
            data_split_stratify= False,
            fold_strategy="timeseries",
            target="target_direction",
            ignore_features=["tarih", "date", "nextHour"],
            categorical_features=["Day of Week"],
            preprocess=True, # Özellik dönüşümünü ve ölçeklendirmeyi devre dışı bırakın
            verbose=True)
# Out:
# <style type="text/css">
# #T_82bfe_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_82bfe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_82bfe_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_82bfe_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_82bfe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_82bfe_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_82bfe_row0_col1" class="data row0 col1" >831</td>
#     </tr>
#     <tr>
#       <th id="T_82bfe_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_82bfe_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_82bfe_row1_col1" class="data row1 col1" >target_direction</td>
#     </tr>
#     <tr>
#       <th id="T_82bfe_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_82bfe_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_82bfe_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_82bfe_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_82bfe_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_82bfe_row3_col1" class="data row3 col1" >ENERGY_DEFICIT: 0, ENERGY_SURPLUS: 1, IN_BALANCE: 2</td>
#     </tr>
#     <tr>
#       <th id="T_82bfe_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_82bfe_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_82bfe_row4_col1" class="data row4 col1" >(34885, 204)</td>
#     </tr>
#     <tr>
#       <th id="T_82bfe_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_82bfe_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_82bfe_row5_col1" class="data row5 col1" >(34885, 207)</td>
#     </tr>
#     <tr>
#       <th id="T_82bfe_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_82bfe_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_82bfe_row6_col1" class="data row6 col1" >(26125, 207)</td>
#     </tr>
#     <tr>
#       <th id="T_82bfe_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_82bfe_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_82bfe_row7_col1" class="data row7 col1" >(8760, 207)</td>
#     </tr>
#     <tr>
#       <th id="T_82bfe_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_82bfe_row8_col0" class="data row8 col0" >Ignore features</td>
#       <td id="T_82bfe_row8_col1" class="data row8 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_82bfe_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_82bfe_row9_col0" class="data row9 col0" >Numeric features</td>
#       <td id="T_82bfe_row9_col1" class="data row9 col1" >196</td>
#     </tr>
#     <tr>
#       <th id="T_82bfe_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_82bfe_row10_col0" class="data row10 col0" >Categorical features</td>
#       <td id="T_82bfe_row10_col1" class="data row10 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_82bfe_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_82bfe_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_82bfe_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_82bfe_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_82bfe_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_82bfe_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_82bfe_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_82bfe_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_82bfe_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_82bfe_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_82bfe_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_82bfe_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_82bfe_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_82bfe_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_82bfe_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_82bfe_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_82bfe_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_82bfe_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_82bfe_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_82bfe_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_82bfe_row17_col1" class="data row17 col1" >TimeSeriesSplit</td>
#     </tr>
#     <tr>
#       <th id="T_82bfe_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_82bfe_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_82bfe_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_82bfe_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_82bfe_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_82bfe_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_82bfe_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_82bfe_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_82bfe_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_82bfe_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_82bfe_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_82bfe_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_82bfe_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_82bfe_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_82bfe_row22_col1" class="data row22 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_82bfe_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_82bfe_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_82bfe_row23_col1" class="data row23 col1" >6cec</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - "data" parametresi, eğitim veri kümesini belirtir.
#
# - "test_data" parametresi, doğrulama veri kümesini belirtir.
#
# - "data_split_shuffle" parametresi, verilerin karıştırılıp karıştırılmayacağını belirtir.
#
# - "data_split_stratify" parametresi, verilerin ayrıştırılırken oranlarına dikkat edilip edilmeyeceğini belirtir.
#
# - "fold_strategy" parametresi, çapraz doğrulama yöntemini belirtir. Bu örnekte, "timeseries" olarak belirtilmiştir, bu da zaman serisi tabanlı bir çapraz doğrulama yapılacağı anlamına gelir.
#
# - "target" parametresi, hedef değişkeni belirtir.
#
# - "ignore_features" parametresi, model eğitimi için kullanılmayacak özellikleri belirtir.
#
# - "categorical_features" parametresi, kategorik özellikleri belirtir.
#
# - "preprocess" parametresi, özellik dönüşümlerini ve ölçeklendirmeleri etkinleştirir veya devre dışı bırakır.
#
# - "verbose" parametresi, işlem sırasında ayrıntılı çıktı verir.

# %%
#best_model = compare_models()

# %% [markdown]
# PyCaret'ın compare_models fonksiyonu, bu kütüphanenin barındırdığı bütün alogirtmaları eğitir, sonuçlarını test eder ve modelleri başarılarına göre sıralar. (Bu kısım zamandan tasarruf etmek için tekrar tekrar çalıştırılmamak commente alınmıştır. Bu adımda en başarılı model LightGBM çıkmıştır)

# %%
#lightgbm modelinin eğitilmesi
model = create_model('lightgbm')
# Out:
# <style type="text/css">
# #T_5bfd5_row10_col0, #T_5bfd5_row10_col1, #T_5bfd5_row10_col2, #T_5bfd5_row10_col3, #T_5bfd5_row10_col4, #T_5bfd5_row10_col5, #T_5bfd5_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_5bfd5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5bfd5_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_5bfd5_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_5bfd5_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_5bfd5_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_5bfd5_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_5bfd5_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_5bfd5_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5bfd5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5bfd5_row0_col0" class="data row0 col0" >0.7234</td>
#       <td id="T_5bfd5_row0_col1" class="data row0 col1" >0.7925</td>
#       <td id="T_5bfd5_row0_col2" class="data row0 col2" >0.7234</td>
#       <td id="T_5bfd5_row0_col3" class="data row0 col3" >0.6891</td>
#       <td id="T_5bfd5_row0_col4" class="data row0 col4" >0.7047</td>
#       <td id="T_5bfd5_row0_col5" class="data row0 col5" >0.3987</td>
#       <td id="T_5bfd5_row0_col6" class="data row0 col6" >0.4026</td>
#     </tr>
#     <tr>
#       <th id="T_5bfd5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5bfd5_row1_col0" class="data row1 col0" >0.7385</td>
#       <td id="T_5bfd5_row1_col1" class="data row1 col1" >0.8077</td>
#       <td id="T_5bfd5_row1_col2" class="data row1 col2" >0.7385</td>
#       <td id="T_5bfd5_row1_col3" class="data row1 col3" >0.6971</td>
#       <td id="T_5bfd5_row1_col4" class="data row1 col4" >0.7156</td>
#       <td id="T_5bfd5_row1_col5" class="data row1 col5" >0.3917</td>
#       <td id="T_5bfd5_row1_col6" class="data row1 col6" >0.3980</td>
#     </tr>
#     <tr>
#       <th id="T_5bfd5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5bfd5_row2_col0" class="data row2 col0" >0.7309</td>
#       <td id="T_5bfd5_row2_col1" class="data row2 col1" >0.8143</td>
#       <td id="T_5bfd5_row2_col2" class="data row2 col2" >0.7309</td>
#       <td id="T_5bfd5_row2_col3" class="data row2 col3" >0.7066</td>
#       <td id="T_5bfd5_row2_col4" class="data row2 col4" >0.7080</td>
#       <td id="T_5bfd5_row2_col5" class="data row2 col5" >0.4434</td>
#       <td id="T_5bfd5_row2_col6" class="data row2 col6" >0.4607</td>
#     </tr>
#     <tr>
#       <th id="T_5bfd5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5bfd5_row3_col0" class="data row3 col0" >0.7314</td>
#       <td id="T_5bfd5_row3_col1" class="data row3 col1" >0.8015</td>
#       <td id="T_5bfd5_row3_col2" class="data row3 col2" >0.7314</td>
#       <td id="T_5bfd5_row3_col3" class="data row3 col3" >0.7082</td>
#       <td id="T_5bfd5_row3_col4" class="data row3 col4" >0.7195</td>
#       <td id="T_5bfd5_row3_col5" class="data row3 col5" >0.4604</td>
#       <td id="T_5bfd5_row3_col6" class="data row3 col6" >0.4615</td>
#     </tr>
#     <tr>
#       <th id="T_5bfd5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5bfd5_row4_col0" class="data row4 col0" >0.7444</td>
#       <td id="T_5bfd5_row4_col1" class="data row4 col1" >0.8402</td>
#       <td id="T_5bfd5_row4_col2" class="data row4 col2" >0.7444</td>
#       <td id="T_5bfd5_row4_col3" class="data row4 col3" >0.7238</td>
#       <td id="T_5bfd5_row4_col4" class="data row4 col4" >0.7313</td>
#       <td id="T_5bfd5_row4_col5" class="data row4 col5" >0.4870</td>
#       <td id="T_5bfd5_row4_col6" class="data row4 col6" >0.4918</td>
#     </tr>
#     <tr>
#       <th id="T_5bfd5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5bfd5_row5_col0" class="data row5 col0" >0.7128</td>
#       <td id="T_5bfd5_row5_col1" class="data row5 col1" >0.8121</td>
#       <td id="T_5bfd5_row5_col2" class="data row5 col2" >0.7128</td>
#       <td id="T_5bfd5_row5_col3" class="data row5 col3" >0.6645</td>
#       <td id="T_5bfd5_row5_col4" class="data row5 col4" >0.6856</td>
#       <td id="T_5bfd5_row5_col5" class="data row5 col5" >0.4393</td>
#       <td id="T_5bfd5_row5_col6" class="data row5 col6" >0.4469</td>
#     </tr>
#     <tr>
#       <th id="T_5bfd5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5bfd5_row6_col0" class="data row6 col0" >0.6737</td>
#       <td id="T_5bfd5_row6_col1" class="data row6 col1" >0.7813</td>
#       <td id="T_5bfd5_row6_col2" class="data row6 col2" >0.6737</td>
#       <td id="T_5bfd5_row6_col3" class="data row6 col3" >0.6561</td>
#       <td id="T_5bfd5_row6_col4" class="data row6 col4" >0.6565</td>
#       <td id="T_5bfd5_row6_col5" class="data row6 col5" >0.3735</td>
#       <td id="T_5bfd5_row6_col6" class="data row6 col6" >0.3759</td>
#     </tr>
#     <tr>
#       <th id="T_5bfd5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5bfd5_row7_col0" class="data row7 col0" >0.7335</td>
#       <td id="T_5bfd5_row7_col1" class="data row7 col1" >0.8278</td>
#       <td id="T_5bfd5_row7_col2" class="data row7 col2" >0.7335</td>
#       <td id="T_5bfd5_row7_col3" class="data row7 col3" >0.6974</td>
#       <td id="T_5bfd5_row7_col4" class="data row7 col4" >0.7147</td>
#       <td id="T_5bfd5_row7_col5" class="data row7 col5" >0.4900</td>
#       <td id="T_5bfd5_row7_col6" class="data row7 col6" >0.4927</td>
#     </tr>
#     <tr>
#       <th id="T_5bfd5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5bfd5_row8_col0" class="data row8 col0" >0.7958</td>
#       <td id="T_5bfd5_row8_col1" class="data row8 col1" >0.8704</td>
#       <td id="T_5bfd5_row8_col2" class="data row8 col2" >0.7958</td>
#       <td id="T_5bfd5_row8_col3" class="data row8 col3" >0.7708</td>
#       <td id="T_5bfd5_row8_col4" class="data row8 col4" >0.7806</td>
#       <td id="T_5bfd5_row8_col5" class="data row8 col5" >0.5176</td>
#       <td id="T_5bfd5_row8_col6" class="data row8 col6" >0.5211</td>
#     </tr>
#     <tr>
#       <th id="T_5bfd5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5bfd5_row9_col0" class="data row9 col0" >0.6796</td>
#       <td id="T_5bfd5_row9_col1" class="data row9 col1" >0.8069</td>
#       <td id="T_5bfd5_row9_col2" class="data row9 col2" >0.6796</td>
#       <td id="T_5bfd5_row9_col3" class="data row9 col3" >0.6619</td>
#       <td id="T_5bfd5_row9_col4" class="data row9 col4" >0.6458</td>
#       <td id="T_5bfd5_row9_col5" class="data row9 col5" >0.3546</td>
#       <td id="T_5bfd5_row9_col6" class="data row9 col6" >0.3822</td>
#     </tr>
#     <tr>
#       <th id="T_5bfd5_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_5bfd5_row10_col0" class="data row10 col0" >0.7264</td>
#       <td id="T_5bfd5_row10_col1" class="data row10 col1" >0.8155</td>
#       <td id="T_5bfd5_row10_col2" class="data row10 col2" >0.7264</td>
#       <td id="T_5bfd5_row10_col3" class="data row10 col3" >0.6976</td>
#       <td id="T_5bfd5_row10_col4" class="data row10 col4" >0.7062</td>
#       <td id="T_5bfd5_row10_col5" class="data row10 col5" >0.4356</td>
#       <td id="T_5bfd5_row10_col6" class="data row10 col6" >0.4433</td>
#     </tr>
#     <tr>
#       <th id="T_5bfd5_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_5bfd5_row11_col0" class="data row11 col0" >0.0325</td>
#       <td id="T_5bfd5_row11_col1" class="data row11 col1" >0.0241</td>
#       <td id="T_5bfd5_row11_col2" class="data row11 col2" >0.0325</td>
#       <td id="T_5bfd5_row11_col3" class="data row11 col3" >0.0322</td>
#       <td id="T_5bfd5_row11_col4

# %%
#modelin hiperparametre optimizasyonu yapılma aşaması
tuned_model = tune_model(model,optimize='F1')
# Out:
# <style type="text/css">
# #T_961b9_row10_col0, #T_961b9_row10_col1, #T_961b9_row10_col2, #T_961b9_row10_col3, #T_961b9_row10_col4, #T_961b9_row10_col5, #T_961b9_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_961b9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_961b9_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_961b9_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_961b9_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_961b9_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_961b9_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_961b9_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_961b9_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_961b9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_961b9_row0_col0" class="data row0 col0" >0.7301</td>
#       <td id="T_961b9_row0_col1" class="data row0 col1" >0.7995</td>
#       <td id="T_961b9_row0_col2" class="data row0 col2" >0.7301</td>
#       <td id="T_961b9_row0_col3" class="data row0 col3" >0.6957</td>
#       <td id="T_961b9_row0_col4" class="data row0 col4" >0.7107</td>
#       <td id="T_961b9_row0_col5" class="data row0 col5" >0.4097</td>
#       <td id="T_961b9_row0_col6" class="data row0 col6" >0.4150</td>
#     </tr>
#     <tr>
#       <th id="T_961b9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_961b9_row1_col0" class="data row1 col0" >0.7427</td>
#       <td id="T_961b9_row1_col1" class="data row1 col1" >0.8079</td>
#       <td id="T_961b9_row1_col2" class="data row1 col2" >0.7427</td>
#       <td id="T_961b9_row1_col3" class="data row1 col3" >0.7020</td>
#       <td id="T_961b9_row1_col4" class="data row1 col4" >0.7204</td>
#       <td id="T_961b9_row1_col5" class="data row1 col5" >0.4035</td>
#       <td id="T_961b9_row1_col6" class="data row1 col6" >0.4094</td>
#     </tr>
#     <tr>
#       <th id="T_961b9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_961b9_row2_col0" class="data row2 col0" >0.7301</td>
#       <td id="T_961b9_row2_col1" class="data row2 col1" >0.8173</td>
#       <td id="T_961b9_row2_col2" class="data row2 col2" >0.7301</td>
#       <td id="T_961b9_row2_col3" class="data row2 col3" >0.7043</td>
#       <td id="T_961b9_row2_col4" class="data row2 col4" >0.7091</td>
#       <td id="T_961b9_row2_col5" class="data row2 col5" >0.4451</td>
#       <td id="T_961b9_row2_col6" class="data row2 col6" >0.4584</td>
#     </tr>
#     <tr>
#       <th id="T_961b9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_961b9_row3_col0" class="data row3 col0" >0.7208</td>
#       <td id="T_961b9_row3_col1" class="data row3 col1" >0.8020</td>
#       <td id="T_961b9_row3_col2" class="data row3 col2" >0.7208</td>
#       <td id="T_961b9_row3_col3" class="data row3 col3" >0.6981</td>
#       <td id="T_961b9_row3_col4" class="data row3 col4" >0.7089</td>
#       <td id="T_961b9_row3_col5" class="data row3 col5" >0.4378</td>
#       <td id="T_961b9_row3_col6" class="data row3 col6" >0.4392</td>
#     </tr>
#     <tr>
#       <th id="T_961b9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_961b9_row4_col0" class="data row4 col0" >0.7419</td>
#       <td id="T_961b9_row4_col1" class="data row4 col1" >0.8312</td>
#       <td id="T_961b9_row4_col2" class="data row4 col2" >0.7419</td>
#       <td id="T_961b9_row4_col3" class="data row4 col3" >0.7218</td>
#       <td id="T_961b9_row4_col4" class="data row4 col4" >0.7284</td>
#       <td id="T_961b9_row4_col5" class="data row4 col5" >0.4810</td>
#       <td id="T_961b9_row4_col6" class="data row4 col6" >0.4867</td>
#     </tr>
#     <tr>
#       <th id="T_961b9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_961b9_row5_col0" class="data row5 col0" >0.7036</td>
#       <td id="T_961b9_row5_col1" class="data row5 col1" >0.8034</td>
#       <td id="T_961b9_row5_col2" class="data row5 col2" >0.7036</td>
#       <td id="T_961b9_row5_col3" class="data row5 col3" >0.6552</td>
#       <td id="T_961b9_row5_col4" class="data row5 col4" >0.6762</td>
#       <td id="T_961b9_row5_col5" class="data row5 col5" >0.4207</td>
#       <td id="T_961b9_row5_col6" class="data row5 col6" >0.4283</td>
#     </tr>
#     <tr>
#       <th id="T_961b9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_961b9_row6_col0" class="data row6 col0" >0.6754</td>
#       <td id="T_961b9_row6_col1" class="data row6 col1" >0.7721</td>
#       <td id="T_961b9_row6_col2" class="data row6 col2" >0.6754</td>
#       <td id="T_961b9_row6_col3" class="data row6 col3" >0.6401</td>
#       <td id="T_961b9_row6_col4" class="data row6 col4" >0.6571</td>
#       <td id="T_961b9_row6_col5" class="data row6 col5" >0.3771</td>
#       <td id="T_961b9_row6_col6" class="data row6 col6" >0.3792</td>
#     </tr>
#     <tr>
#       <th id="T_961b9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_961b9_row7_col0" class="data row7 col0" >0.7322</td>
#       <td id="T_961b9_row7_col1" class="data row7 col1" >0.8326</td>
#       <td id="T_961b9_row7_col2" class="data row7 col2" >0.7322</td>
#       <td id="T_961b9_row7_col3" class="data row7 col3" >0.6961</td>
#       <td id="T_961b9_row7_col4" class="data row7 col4" >0.7135</td>
#       <td id="T_961b9_row7_col5" class="data row7 col5" >0.4877</td>
#       <td id="T_961b9_row7_col6" class="data row7 col6" >0.4903</td>
#     </tr>
#     <tr>
#       <th id="T_961b9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_961b9_row8_col0" class="data row8 col0" >0.7928</td>
#       <td id="T_961b9_row8_col1" class="data row8 col1" >0.8615</td>
#       <td id="T_961b9_row8_col2" class="data row8 col2" >0.7928</td>
#       <td id="T_961b9_row8_col3" class="data row8 col3" >0.7775</td>
#       <td id="T_961b9_row8_col4" class="data row8 col4" >0.7753</td>
#       <td id="T_961b9_row8_col5" class="data row8 col5" >0.5067</td>
#       <td id="T_961b9_row8_col6" class="data row8 col6" >0.5111</td>
#     </tr>
#     <tr>
#       <th id="T_961b9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_961b9_row9_col0" class="data row9 col0" >0.6712</td>
#       <td id="T_961b9_row9_col1" class="data row9 col1" >0.8012</td>
#       <td id="T_961b9_row9_col2" class="data row9 col2" >0.6712</td>
#       <td id="T_961b9_row9_col3" class="data row9 col3" >0.6631</td>
#       <td id="T_961b9_row9_col4" class="data row9 col4" >0.6368</td>
#       <td id="T_961b9_row9_col5" class="data row9 col5" >0.3364</td>
#       <td id="T_961b9_row9_col6" class="data row9 col6" >0.3634</td>
#     </tr>
#     <tr>
#       <th id="T_961b9_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_961b9_row10_col0" class="data row10 col0" >0.7241</td>
#       <td id="T_961b9_row10_col1" class="data row10 col1" >0.8129</td>
#       <td id="T_961b9_row10_col2" class="data row10 col2" >0.7241</td>
#       <td id="T_961b9_row10_col3" class="data row10 col3" >0.6954</td>
#       <td id="T_961b9_row10_col4" class="data row10 col4" >0.7036</td>
#       <td id="T_961b9_row10_col5" class="data row10 col5" >0.4306</td>
#       <td id="T_961b9_row10_col6" class="data row10 col6" >0.4381</td>
#     </tr>
#     <tr>
#       <th id="T_961b9_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_961b9_row11_col0" class="data row11 col0" >0.0334</td>
#       <td id="T_961b9_row11_col1" class="data row11 col1" >0.0230</td>
#       <td id="T_961b9_row11_col2" class="data row11 col2" >0.0334</td>
#       <td id="T_961b9_row11_col3" class="data row11 col3" >0.0364</td>
#       <td id="T_961b9_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
#model eğitiminin son aşaması. finalize_model fonksiyonu ile validasyon seti de modele öğretilir ve test verisini tahmin etmek içni hazır olur.
f = finalize_model(tuned_model)

# %%
plot_model(f,plot='confusion_matrix')

# %% [markdown]
# Yukarıda verilen matris, modelin sınıflandırma performansının farklı sınıflar için nasıl olduğunu göstermektedir. Model sınıf 1'i doğru şekilde sınıflandırmada oldukça başarılı olurken, sınıf 2'yi sınıflandırmada daha düşük bir başarı elde eder. Sınıf 3 ise oldukça az sayıda örnek içermesine rağmen, model tarafından sınıflandırılmada en yüksek hata oranına sahiptir.

# %%
predictions = predict_model(f, data=test_data)
accuracy = accuracy_score(predictions['target_direction'], predictions['prediction_label'])
print("Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# <style type="text/css">
# </style>
# <table id="T_fee1e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fee1e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_fee1e_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_fee1e_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_fee1e_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_fee1e_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_fee1e_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_fee1e_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_fee1e_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fee1e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fee1e_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_fee1e_row0_col1" class="data row0 col1" >0.8288</td>
#       <td id="T_fee1e_row0_col2" class="data row0 col2" >0.8129</td>
#       <td id="T_fee1e_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_fee1e_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_fee1e_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_fee1e_row0_col6" class="data row0 col6" >0.4003</td>
#       <td id="T_fee1e_row0_col7" class="data row0 col7" >0.4134</td>
#     </tr>
#   </tbody>
# </table>
# Accuracy: 82.88%

# %%
plot_model(f,plot="pr")

# %% [markdown]
# Yukarıdaki PR (Precision-Recall) eğrisi, modelin doğru pozitif tahminlerinin sayısını yanıltıcı pozitif tahminlerin sayısına oranını göstererek, modelin sınıflandırma performansının ne kadar iyi olduğunu yansıtır. Yüksek bir ortalama hassasiyet değeri, modelin doğru sınıflandırma yapma becerisi olduğunu ve yanıltıcı tahminlerin oranının düşük olduğunu gösterir.

# %%
plot_model(model,plot="learning",use_train_data=False)

# %% [markdown]
# Öğrenme eğrisi, başlangıçta düşük örnek sayısı nedeniyle aşırı uyma olasılığı yüksek olduğundan, örnek sayısı arttıkça modelin genelleme yapma becerisinin geliştiğini gösterir. Öğrenme eğrisi, özellikle eğitim skoru ve çapraz doğrulama skoru arasındaki açık farkın daraldığı noktaları vurgulayarak, modelin en iyi performansını hangi noktada gösterdiğini belirleyebilir. Bu durumda, örnek sayısı arttıkça, modelin eğitim ve doğrulama skorları arasındaki fark daralmış ve modelin daha iyi bir genelleme yapma yeteneği olduğu görülmüştür.

# %%
plot_model(f,plot="feature",use_train_data=False)

# %% [markdown]
# Bu feature importance grafiği, bir makine öğrenimi modelinin hangi özelliklerin (features) sınıflandırmada ne kadar önemli olduğunu gösterir.
#
# Grafiğe göre, en önemli özellik "hour"dur ve 700 puan ile özellikler arasında en yüksek öneme sahiptir. Saat özelliği, modelin sınıflandırma yaparken en fazla bilgiyi sağlayan özelliktir.
#
# İkinci en önemli özellik "cumulative_avg"dir ve 440 puan ile özellikler arasında ikinci en yüksek öneme sahiptir. "cumulative_avg", modelin sınıflandırma performansında büyük bir rol oynayan diğer bir özelliktir.
#
# "net" özelliği de 280 puan ile önemli bir özelliktir ve sınıflandırmada etkili bir faktördür. "month" ve "day" özellikleri de önemli özellikler olarak dikkat çekiyor, ancak "hour" ve "cumulative_avg" kadar önemli değiller.
#
# Sonuç olarak, bu grafik, modelin sınıflandırma yaparken hangi özelliklere daha fazla odaklanması gerektiğini ve hangi özelliklerin en yüksek etkiye sahip olduğunu göstermektedir. "hour" ve "cumulative_avg" özelliklerinin sınıflandırmada en önemli özellikler olduğu, "net", "month" ve "day" özelliklerinin ise ikinci derecede öneme sahip olduğu görülmektedir.

# %%
plot_model(f,plot="boundary",use_train_data=False)

# %%
def yuzdeler(model, df, prediction_label, y):
    preds = predict_model(model, df)[[y, 'prediction_label', 'prediction_score']]
    son = pd.DataFrame()
    preds = preds[preds['prediction_label']==prediction_label]
    arange = np.arange(0.5, 1, 0.005)
    for i in arange:
        deneme = preds[preds['prediction_score']>=i]
        yuzde = round(accuracy_score(deneme[y], deneme['prediction_label']), 3)
        dicto = {'Thresh': i, 'Yüzde': yuzde, 'Len': len(deneme)}
        son = son.append(pd.DataFrame(dicto, index=[0]), ignore_index=True)
        son = son.dropna(axis=0)
    #son.to_csv(f"precs/{y}model_{prediction_label}.csv", index=False)
    return son.sort_values('Thresh', ascending=False)

# %% [markdown]
# Bu fonksiyon, bir sınıflandırma modelinin performansını farklı eşik (threshold) değerleri için yüzde doğruluk (accuracy) oranı olarak değerlendiren bir fonksiyondur. Fonksiyon, model, veri çerçevesi (df), tahmin edilen etiket (prediction_label) ve gerçek etiket (y) gibi argümanları alır.

# %%
predict_model(f, test_data)[["target_direction", 'prediction_label', 'prediction_score']]
# Out:
# <style type="text/css">
# </style>
# <table id="T_628e1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_628e1_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_628e1_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_628e1_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_628e1_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_628e1_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_628e1_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_628e1_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_628e1_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_628e1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_628e1_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_628e1_row0_col1" class="data row0 col1" >0.8243</td>
#       <td id="T_628e1_row0_col2" class="data row0 col2" >0.8049</td>
#       <td id="T_628e1_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_628e1_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_628e1_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_628e1_row0_col6" class="data row0 col6" >0.4147</td>
#       <td id="T_628e1_row0_col7" class="data row0 col7" >0.4200</td>
#     </tr>
#   </tbody>
# </table>
#       target_direction prediction_label  prediction_score
# 35064   ENERGY_SURPLUS   ENERGY_SURPLUS            0.4907
# 35065   ENERGY_SURPLUS   ENERGY_DEFICIT            0.6263
# 35066   ENERGY_SURPLUS   ENERGY_DEFICIT            0.6466
# 35067   ENERGY_SURPLUS   ENERGY_SURPLUS            0.6069
# 35068   ENERGY_SURPLUS   ENERGY_SURPLUS            0.5794
# ...                ...              ...               ...
# 43816   ENERGY_DEFICIT   ENERGY_DEFICIT            0.7068
# 43817   ENERGY_DEFICIT   ENERGY_DEFICIT            0.5402
# 43818   ENERGY_SURPLUS   ENERGY_DEFICIT            0.8790
# 43819   ENERGY_SURPLUS   ENERGY_DEFICIT            0.8913
# 43820   ENERGY_SURPLUS   ENERGY_DEFICIT            0.5740
#
# [8757 rows x 3 columns]

# %%
p = predict_model(f,data =test_data)

px =p[["date","target_direction",'prediction_label','prediction_score']]
# Out:
# <style type="text/css">
# </style>
# <table id="T_e5a66">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e5a66_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e5a66_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_e5a66_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_e5a66_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_e5a66_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_e5a66_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_e5a66_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_e5a66_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e5a66_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e5a66_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_e5a66_row0_col1" class="data row0 col1" >0.8243</td>
#       <td id="T_e5a66_row0_col2" class="data row0 col2" >0.8049</td>
#       <td id="T_e5a66_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_e5a66_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_e5a66_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_e5a66_row0_col6" class="data row0 col6" >0.4147</td>
#       <td id="T_e5a66_row0_col7" class="data row0 col7" >0.4200</td>
#     </tr>
#   </tbody>
# </table>

# %%
yuzdeler(f,test_data,"ENERGY_DEFICIT","target_direction").head(50)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a98e2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a98e2_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a98e2_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_a98e2_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_a98e2_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_a98e2_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_a98e2_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_a98e2_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_a98e2_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a98e2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a98e2_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_a98e2_row0_col1" class="data row0 col1" >0.8243</td>
#       <td id="T_a98e2_row0_col2" class="data row0 col2" >0.8049</td>
#       <td id="T_a98e2_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a98e2_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_a98e2_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_a98e2_row0_col6" class="data row0 col6" >0.4147</td>
#       <td id="T_a98e2_row0_col7" class="data row0 col7" >0.4200</td>
#     </tr>
#   </tbody>
# </table>
#     Thresh  Yüzde   Len
# 97   0.985  0.992   247
# 96   0.980  0.988   566
# 95   0.975  0.985   677
# 94   0.970  0.985   793
# 93   0.965  0.982   920
# 92   0.960  0.979  1102
# 91   0.955  0.972  1278
# 90   0.950  0.967  1435
# 89   0.945  0.963  1583
# 88   0.940  0.964  1727
# 87   0.935  0.961  1859
# 86   0.930  0.960  1978
# 85   0.925  0.957  2115
# 84   0.920  0.955  2239
# 83   0.915  0.956  2356
# 82   0.910  0.955  2462
# 81   0.905  0.952  2569
# 80   0.900  0.951  2683
# 79   0.895  0.949  2784
# 78   0.890  0.949  2869
# 77   0.885  0.949  2961
# 76   0.880  0.949  3057
# 75   0.875  0.948  3140
# 74   0.870  0.947  3215
# 73   0.865  0.946  3290
# 72   0.860  0.944  3359
# 71   0.855  0.943  3428
# 70   0.850  0.940  3504
# 69   0.845  0.940  3578
# 68   0.840  0.937  3643
# 67   0.835  0.936  3706
# 66   0.830  0.934  3759
# 65   0.825  0.935  3814
# 64   0.820  0.933  3874
# 63   0.815  0.933  3942
# 62   0.810  0.931  4008
# 61   0.805  0.931  4079
# 60   0.800  0.930  4149
# 59   0.795  0.929  4209
# 58   0.790  0.928  4265
# 57   0.785  0.927  4328
# 56   0.780  0.926  4397
# 55   0.775  0.926  4468
# 54   0.770  0.924  4528
# 53   0.765  0.924  4578
# 52   0.760  0.922  4629
# 51   0.755  0.921  4691
# 50   0.750  0.921  4753
# 49   0.745  0.920  4812
# 48   0.740  0.919  4867

# %% [markdown]
# Bu çıktı, belirli bir tahmin etiketi için tahmin edilen olasılık eşiğine göre modelin doğruluğunu (accuracy) ve bu eşikteki örnek sayısını gösterir.
#
# Thresh: Tahmin olasılığının eşiği.
# Yüzde: Belirtilen eşiğe göre modelin doğruluk yüzdesi.
# Len: Belirtilen eşiğe göre örnek sayısı.
# Örneğin, Thresh değeri 0.835 için, modelin doğruluğu %100'dür ve bu eşiği karşılayan sadece 1 örnek vardır. Benzer şekilde, Thresh değeri 0.820 için, modelin doğruluğu %83.3'tür ve bu eşiği karşılayan 12 örnek vardır.
#
# Bu tür analizler, belirli bir eşiğe göre modelin performansını değerlendirmenize ve en uygun eşiği belirlemenize olanak tanır. Ayrıca, belirli eşiklerde modelin ne kadar güvenilir olduğunu anlamanıza da yardımcı olur. Dikkate almanız gereken önemli bir nokta, daha yüksek eşik değerlerinde örnek sayısının azalması ve dolayısıyla modelin doğruluğunun daha az istikrarlı hale gelmesidir.

# %% [markdown]
# ## 3.4. Dış Verilerin Eklenmesi

# %%
base_url = "https://seffaflik.epias.com.tr/transparency/service/market/bpm-order-summary"
start_date = "2018-01-01"
end_date = "2022-12-31"

params = {
    "startDate": start_date,
    "endDate": end_date
}

dgp_response = requests.get(base_url, params=params)
dgp_data = dgp_response.json()


# 'bpmOrderSummaryList' anahtarını kullanarak ilgili bilgileri elde edin
dgp_list = dgp_data['body']["bpmOrderSummaryList"]

# Tüm saatler için ilgili verileri içeren bir DataFrame oluşturun
hour_data = []

for hour_info in dgp_list:
    hour_info["tarih"] = pd.to_datetime(hour_info["date"], format="%Y-%m-%dT%H:%M:%S.%f%z")
    hour_data.append(hour_info)

# Tüm saatlerin verilerini içeren tek bir DataFrame oluşturun
dgp_df = pd.DataFrame(hour_data)

# %% [markdown]
# ### 3.4.1 Özel Günler
#
# Özel günler, zaamn serisi analizinde oldukça faydalıdır. Belirli bir tarihsel veri çerçevesinde özel günlerin varlığı, bu özel günlerin satış, trafiğin yoğunluğu, vb. gibi farklı verilerin analizinde kullanılabilir.

# %%
df = dgp_df.copy()
dfs = pd.read_html('http://www.bulanik.gov.tr/ulkemizde-kutlanan-onemli-gun-ve-haftalar')
i_days = pd.concat(dfs)
conv_months = {'Ocak':1,'Şubat':2,'Mart':3,'Nisan':4,'Mayıs':5,'Haziran':6,'Temmuz':7,'Ağustos':8,'Eylül':9,'Ekim':10,'Kasım':11,'Aralık':12}
i_days = i_days[i_days[0].str.contains('Günü')]
i_days=i_days[~i_days[1].str.contains('ilk')]
i_days = i_days[~i_days[1].str.contains('-')]
new_months = i_days[1].str.split(' ',expand=True)[1].replace(conv_months)

i_days['days'] = i_days[1].str.split(' ',expand=True)[0]
i_days['months'] = new_months

i_days['days']=i_days['days'].astype('int64')

df['Year'] = df['tarih'].dt.year
df['Month'] = df['tarih'].dt.strftime('%B')
df['Day'] = df['tarih'].dt.day
df['Day of Week'] = df['tarih'].dt.strftime('%A')
df['Day of Year'] = df['tarih'].dt.day_of_year
df['Series'] = np.arange(0,len(df))+1
df['decmonth'] = df['tarih'].dt.month

# %% [markdown]
# ### 3.4.2 Tatiller

# %%
import holidays

tr_holidays = holidays.TR()

df = df.reset_index()

holidays = np.zeros(len(df))


for i in range(len(holidays)):
    if df['tarih'].dt.date[i] in tr_holidays:
        holidays[i] = 1
        
df['Holidays'] = holidays

df['is_Weekend'] = np.where(((df['Day of Week']=='Saturday') | (df['Day of Week']=='Sunday')),1,0)

df['Holidays'] = df['Holidays'].astype('int').astype('category')
df['is_Weekend'] = df['is_Weekend'].astype('category')

# %%
new_df = pd.merge(df, i_days,  how='left', left_on=['decmonth','Day'], right_on = ['months','days'])
new_df = new_df.drop([1,'months'],axis=1).rename(columns={0:'Important Days'})
new_df['Important Days'] = new_df['Important Days'].fillna('-')

# %%
new_df.to_csv('extended_data.csv',index=False)

# %% [markdown]
# ### 3.4.3 Hava Durumu ve Yağış Verisi
#
# Enerji talebi, hava durumu gibi çeşitli faktörlere bağlı olarak değişkenlik gösterir. Örneğin, sıcaklık, nem, rüzgar hızı ve güneş ışınımı gibi parametreler, enerji talebini etkileyen ısıtma, soğutma ve aydınlatma ihtiyacını belirler. Aynı şekilde, enerji arzı da hava durumuna bağlı olarak değişebilir. Özellikle yenilenebilir enerji kaynaklarından (RES) elektrik üretimi, rüzgar ve güneş gibi hava koşullarına bağlıdır. Bu nedenle, RES’in enerji karışımındaki payı arttıkça, enerji arzının öngörülebilirliği azalır ve şebeke dengesizlikleri daha büyük olur.
#
# Bu bağlamda, hava durumu verilerinin enerji sektöründe dengesizlik yönü tahmini için gerekli olduğu açıktır. Hava durumu verileri, enerji talebi ve arzı modellerinin girdisi olarak kullanılabilir.

# %% [markdown]
# #### 3.4.3.1 Türkiyedeki En Büyük 10 Enerji Üretim Merkezlerinin Toplanması (Güneş,Rüzgar,Hidroelektrik)
#
# Bu aşamada, Türkiye'nin en büyük 10 enerji üretim merkezlerinin bilgileri toplanmaktadır. Buradaki amaç, daha sonra toplanacak havadurumu veri seti için hangi iller bazında hava durumu, yağış ve rüzgar verisinin toplanacağına karar vermektir. Bütün illerin verisini almak, overfitting problemine yol açabileceği için yalnızca bu şehirler toplanmıştır. Öncelikle bu listeler enerjiatlasi.com sitesinden alınmıştır ve daha sonra iller listelenerek bu iller bazında havadurumu,rüzgar,yağış ve güneş ile alakalı veriler çekilmiştir

# %%
def scrape_table_from_url(url, type):
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    table_html = str(soup.find_all('table'))
    if type == 'gunes':
        df = pd.read_html(table_html)[0]
    elif type == 'ruzgar':
        df = pd.read_html(table_html)[0]
    elif type == 'hidroelektrik':
        df = pd.read_html(table_html)[0]
    return df


url = 'https://www.enerjiatlasi.com/en-buyuk/gunes'
df_gunes = scrape_table_from_url(url, 'gunes')

url = 'https://www.enerjiatlasi.com/en-buyuk/ruzgar'
df_ruzgar = scrape_table_from_url(url, 'ruzgar')

url = 'https://www.enerjiatlasi.com/en-buyuk/hidroelektrik'
df_hidroelektrik = scrape_table_from_url(url, 'hidroelektrik')

df = pd.concat([df_ruzgar, df_hidroelektrik], ignore_index=True)

# %%
illist = df['İl'].unique().tolist()

# %%
weather_df = pd.DataFrame()
enddate = datetime.today()
startdate = 0
for j in range(1,65):
    citydf1 = pd.DataFrame()    
    startdate = enddate - dt.timedelta(days=30)
    startst = startdate.strftime('%Y-%m-%d')
    endst = enddate.strftime('%Y-%m-%d')
    for city in illist:
        citydf = pd.DataFrame()
        url = f'https://api.worldweatheronline.com/premium/v1/past-weather.ashx?date={startst}&enddate={endst}&key=7742a8f8a86a4d4ba2d165007230504&q={city},turkey&format=json'
        r = requests.get(url)
        jres = json.loads(r.text)


        try:
            for i in range(len(jres['data']['weather'])):

                my_dict = { 
                            f'{city}_date' : jres['data']['weather'][i]['date'] ,
                            f'{city}_avgtempC' :  jres['data']['weather'][i]['avgtempC'],
                            f'{city}_sunrise' :  jres['data']['weather'][i]['astronomy'][0]['sunrise'],
                            f'{city}_sunset' :  jres['data']['weather'][i]['astronomy'][0]['sunset'],
                            f'{city}_windspeedKmph':  jres['data']['weather'][i]['hourly'][5]['windspeedKmph'],
                            f'{city}_uvIndex' : jres['data']['weather'][i]['uvIndex'],
                            f'{city}_precipitation':  float(jres['data']['weather'][i]['totalSnow_cm']) + (float(jres['data']['weather'][i]['hourly'][5]['precipMM'])*10)


                            }
                citydf = citydf.append(pd.DataFrame(my_dict,index=[i]))
        except Exception as e:
            print(e)
            break

        citydf1 = pd.concat([citydf1,citydf],axis=1)
    weather_df = weather_df.append(citydf1)
    
    enddate = enddate - pd.DateOffset(months=1)
    
weather_df = weather_df.drop_duplicates()
# _date ile biten sütunları bul
date_columns = [col for col in weather_df.columns if col.endswith('_date') and col != 'İstanbul_date']

# istenmeyen sütunları düşür ve istanbul_date'i yeniden adlandır, ardından index olarak ata
weather_df = weather_df.drop(date_columns, axis=1).rename(columns={'İstanbul_date': 'date'}).set_index('date')
weather_df.index = pd.to_datetime(weather_df.index)
weather_df = weather_df.sort_index()

# %%
weather_df.to_csv('weather2.csv')

# %%
import pandas as pd
import pytz

# weather_df veri çerçevesine yeni bir index oluştur. bu index EPIAS'tan gelen tarih değişkeniyle aynı türe sahip olmalı
start_date = pd.Timestamp('2018-01-06', tz=pytz.FixedOffset(180))
weather_df.index = pd.date_range(start=start_date, periods=len(weather_df), freq='D')

# %%
#birden fazla sunset ve sunrise verilerini düşür çünkü dakikalar diğer bölgelerde çok fazla değişmiyor. Türkiye'nin ortası diyebileceğim Sivas merkez olarak baz al.
cols_to_drop = [col for col in weather_df.columns if col.endswith('_sunset') or col.endswith('_sunrise')]
cols_to_drop = list(set(cols_to_drop) - {'Sivas_sunset', 'Sivas_sunrise'})
weather_df = weather_df.drop(cols_to_drop, axis=1)
weather_df = weather_df.rename(columns={'Sivas_sunset': 'sunset', 'Sivas_sunrise': 'sunrise'})

# %%
# sunrise ve sunset değişkenlerini modelin anlayacağı bir standarda dönüştür
def time_to_minutes(time_str):
    hours, minutes = map(int, time_str.split(':'))
    return hours * 60 + minutes

weather_df['sunrise_minutes'] = weather_df['sunrise'].str.extract(r'(\d{1,2}:\d{2})').apply(lambda x: time_to_minutes(x[0]), axis=1)
weather_df['sunset_minutes'] = weather_df['sunset'].str.extract(r'(\d{1,2}:\d{2})').apply(lambda x: time_to_minutes(x[0]), axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [234], line 5
#       2     hours, minutes = map(int, time_str.split(':'))
#       3     return hours * 60 + minutes
# ----> 5 weather_df['sunrise_minutes'] = weather_df['sunrise'].str.extract(r'(\d{1,2}:\d{2})').apply(lambda x: time_to_minutes(x[0]), axis=1)
#       6 weather_df['sunset_minutes'] = weather_df['sunset'].str.extract(r'(\d{1,2}:\d{2})').apply(lambda x: time_to_minutes(x[0]), axis=1)
#
# NameError: name 'weather_df' is not defined

# %%
#birleştirme işlemlerini gerçekleştir
weather_df = weather_df.drop(['sunrise','sunset'],axis=1)
new_df = pd.read_csv('extended_data.csv')
new_df = new_df.drop_duplicates(subset='date').drop('index',axis=1)
new_df['date'] = pd.to_datetime(new_df['date'])


merged_df = pd.merge_asof(new_df, weather_df, left_on='date', right_index=True,allow_exact_matches=False)
merged_df = merged_df.drop('days',axis=1)
merged_df = merged_df.dropna()

# %%
#merged_df.to_csv('merged_df2.csv',index=False)

# %%
merged_df = pd.read_csv('merged_df2.csv')

# %% [markdown]
# ## 3.5 Özellik Çıkarımı

# %% [markdown]
# ### 3.5.1. Covid Flag
#
# TimeSeries problemlerinde Covid-19 dönemine Flag atamak doğru bir yaklaşım olabilir.

# %%
merged_df["covid_flag"] = np.where((merged_df["date"] >= "2020-03-11") & (merged_df["date"] <= "2022-05-31"), 1, 0)

# %% [markdown]
# ### 3.5.2 net Değişkeninden Özellik Çıkarımları
#
# net değişkeninin günlük bazda kümülatif ortalaması ve bir saatten 180 saate (yaklaşık bir hafta) lag'ının alınması doğru bir yaklaşım olabilir.

# %%
merged_df["covid_flag"] = np.where((merged_df["date"] >= "2020-03-11") & (merged_df["date"] <= "2022-05-31"), 1, 0)

#Geçmiş saatlerdeki verilere dayalı özellikler eklemek için 'shift' fonksiyonunun kullanılması

dgp_df["target_direction"] = dgp_df["direction"].shift(-3)

dgp_df["hour"] = dgp_df["tarih"].dt.hour

dgp_df = dgp_df.dropna()

# Gün başlangıçlarının belirlenmesi
dgp_df['day_start'] = dgp_df['hour'] == 0

# Kümülatif ortalama sütununun tanımlanması
dgp_df['cumulative_avg'] = 0.0

# Günlerin başlangıçlarının alınması
day_starts = dgp_df[dgp_df['day_start']].index.tolist()

# Her günün kümülatif ortalamasını hesaplama
for i in range(len(day_starts)):
    start = day_starts[i]
    if i < len(day_starts) - 1:
        end = day_starts[i + 1]
    else:
        end = len(dgp_df)
    cum_sum = 0
    count = 0
    for j in range(start, end):
        cum_sum += dgp_df.loc[j, 'net']
        count += 1
        dgp_df.loc[j, 'cumulative_avg'] = cum_sum / count

for lag in range(1, 180):
    merged_df[f"net_lag{lag}"] = merged_df["net"].shift(lag)

# %% [markdown]
# ## 4. Modelin Yeniden Eğitimi ve Tahminlerin Yapılması

# %%
from pycaret.classification import *

# %%
merged_df['target_direction'].value_counts()
# Out:
# ENERGY_DEFICIT    27613
# ENERGY_SURPLUS    14216
# IN_BALANCE         1692
# Name: target_direction, dtype: int64

# %%
merged_df = merged_df.dropna()

# %% [markdown]
# ## 4.1 Özellik Seçiminin Yapılması
#
# Boruta, Rastgele Orman Sınıflandırıcı algoritması temelinde çalışan bir özellik seçimi yöntemidir. Boruta algoritmasının arkasındaki fikir hem ilginç hem de basittir: orijinal veri kümesindeki tüm özelliklerin rastgele kopyalarını oluştururuz (gölge özellikler olarak adlandırılır) ve bu genişletilmiş veri kümesine dayalı olarak sınıflandırıcılar eğitiriz. Bir özelliğin önemini anlamak için, onu oluşturduğumuz tüm gölge özelliklerle karşılaştırırız. Sadece bu sentetik özelliklerden istatistiksel olarak daha önemli olan özellikleri tutarız, çünkü bunlar model performansına daha fazla katkıda bulunurlar.
#
# Boruta algoritması şu adımları izler:
#
# - Orijinal veri kümesindeki tüm özellikleri kopyalar ve bunları orijinal özelliklerle birleştirir.
# - Gölge özelliklere rastgele değerler atar ve bunları orijinal özelliklerden ayırt etmek için adlarını değiştirir.
# - Rastgele Orman Sınıflandırıcı algoritmasını genişletilmiş veri kümesine uygular ve her bir özelliğin önemini hesaplar.
# - Gölge özelliklerin maksimum önemini alır ve bunu bir eşik değeri olarak kullanır.
# - Orijinal özelliklerden eşik değerinden daha az öneme sahip olanları reddeder, eşit veya daha fazla öneme sahip olanları onaylar veya geçici olarak tutar.
# - Reddedilen veya onaylanan tüm özellikleri kaldırır ve geri kalan gölge özelliklerin değerlerini yeniden karıştırır.
# - Bir sonraki iterasyonda yukarıdaki adımları tekrarlar.
# - Tüm orijinal özellikler reddedilene veya onaylanana kadar veya belirlenen maksimum iterasyon sayısına ulaşılana kadar devam eder.

# %%
from boruta import BorutaPy
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier


var = 'target_direction'

X = merged_df.drop([var,'date','nextHour','tarih'], axis=1)
y = merged_df[var]

rf = RandomForestClassifier(n_jobs=-1, class_weight='balanced', n_estimators=200, max_depth=7, min_samples_split=5)
boruta_feature_selector = BorutaPy(rf, n_estimators='auto', verbose=2, random_state=1, max_iter=100, perc=100)

categorical_columns = X.select_dtypes('object').columns.tolist()  # Kategorik sütun adlarını liste halinde sağlayın

label_encoder = LabelEncoder()

for column in categorical_columns:
    X[column] = label_encoder.fit_transform(X[column])

# Boruta ile özellik seçimini gerçekleştirin
boruta_feature_selector.fit(np.array(X), np.array(y))

import pickle

# Boruta seçicisini 'importances' klasörüne kaydedin
with open(f'{var}_boruta_selector2.pkl', 'wb') as f:
    pickle.dump(boruta_feature_selector, f)

print(f"{var} için Boruta seçici kaydedildi.")
# Out:
# KeyboardInterrupt

# %% [markdown]
# ## 4.2 Modele Girecek Verilerin ve Değişkenlerin Belirlenmesi

# %%
# Modele Boruta'nın çıktı verdiği değişkenlerin verilmesi.
feature_ranks = boruta_feature_selector.ranking_
feature_names = merged_df.drop([var,'date','nextHour','tarih'], axis=1).columns

sorted_features = sorted(zip(feature_names, feature_ranks), key=lambda x: x[1])
top_features = [feature[0] for feature in sorted_features[:boruta_feature_selector.n_features_]]

list1 = merged_df.columns.tolist()
list2 = top_features

ignorelist = [item for item in list1 if item not in list2]
ignorelist.remove('target_direction')
ignorelist = ignorelist +  ['nextHour','tarih']

# %%
valid_data = merged_df[(merged_df['date']<'2022') & (merged_df['date']>'2021')]
test_data = merged_df[(merged_df['date']>'2022')]
train_data = merged_df[(merged_df['date']<'2021') & (merged_df['date']>'2019')]

# %%
clf = setup(data=train_data,
            test_data=valid_data,
            data_split_shuffle=False,
            fold=10,
            data_split_stratify= True,
            fold_strategy="timeseries",
            target="target_direction",
            ignore_features=ignorelist,
            categorical_features=['Year'],
            session_id=1901)
# Out:
# <style type="text/css">
# #T_fc12b_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_fc12b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc12b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_fc12b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc12b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fc12b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_fc12b_row0_col1" class="data row0 col1" >1901</td>
#     </tr>
#     <tr>
#       <th id="T_fc12b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fc12b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_fc12b_row1_col1" class="data row1 col1" >target_direction</td>
#     </tr>
#     <tr>
#       <th id="T_fc12b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fc12b_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_fc12b_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_fc12b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fc12b_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_fc12b_row3_col1" class="data row3 col1" >ENERGY_DEFICIT: 0, ENERGY_SURPLUS: 1, IN_BALANCE: 2</td>
#     </tr>
#     <tr>
#       <th id="T_fc12b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fc12b_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_fc12b_row4_col1" class="data row4 col1" >(26304, 281)</td>
#     </tr>
#     <tr>
#       <th id="T_fc12b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fc12b_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_fc12b_row5_col1" class="data row5 col1" >(26304, 80)</td>
#     </tr>
#     <tr>
#       <th id="T_fc12b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fc12b_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_fc12b_row6_col1" class="data row6 col1" >(17544, 80)</td>
#     </tr>
#     <tr>
#       <th id="T_fc12b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fc12b_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_fc12b_row7_col1" class="data row7 col1" >(8760, 80)</td>
#     </tr>
#     <tr>
#       <th id="T_fc12b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fc12b_row8_col0" class="data row8 col0" >Ignore features</td>
#       <td id="T_fc12b_row8_col1" class="data row8 col1" >203</td>
#     </tr>
#     <tr>
#       <th id="T_fc12b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fc12b_row9_col0" class="data row9 col0" >Ordinal features</td>
#       <td id="T_fc12b_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_fc12b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_fc12b_row10_col0" class="data row10 col0" >Numeric features</td>
#       <td id="T_fc12b_row10_col1" class="data row10 col1" >75</td>
#     </tr>
#     <tr>
#       <th id="T_fc12b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_fc12b_row11_col0" class="data row11 col0" >Categorical features</td>
#       <td id="T_fc12b_row11_col1" class="data row11 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_fc12b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_fc12b_row12_col0" class="data row12 col0" >Preprocess</td>
#       <td id="T_fc12b_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_fc12b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_fc12b_row13_col0" class="data row13 col0" >Imputation type</td>
#       <td id="T_fc12b_row13_col1" class="data row13 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_fc12b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_fc12b_row14_col0" class="data row14 col0" >Numeric imputation</td>
#       <td id="T_fc12b_row14_col1" class="data row14 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_fc12b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_fc12b_row15_col0" class="data row15 col0" >Categorical imputation</td>
#       <td id="T_fc12b_row15_col1" class="data row15 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_fc12b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_fc12b_row16_col0" class="data row16 col0" >Maximum one-hot encoding</td>
#       <td id="T_fc12b_row16_col1" class="data row16 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_fc12b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_fc12b_row17_col0" class="data row17 col0" >Encoding method</td>
#       <td id="T_fc12b_row17_col1" class="data row17 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_fc12b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_fc12b_row18_col0" class="data row18 col0" >Fold Generator</td>
#       <td id="T_fc12b_row18_col1" class="data row18 col1" >TimeSeriesSplit</td>
#     </tr>
#     <tr>
#       <th id="T_fc12b_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_fc12b_row19_col0" class="data row19 col0" >Fold Number</td>
#       <td id="T_fc12b_row19_col1" class="data row19 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_fc12b_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_fc12b_row20_col0" class="data row20 col0" >CPU Jobs</td>
#       <td id="T_fc12b_row20_col1" class="data row20 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_fc12b_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_fc12b_row21_col0" class="data row21 col0" >Use GPU</td>
#       <td id="T_fc12b_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fc12b_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_fc12b_row22_col0" class="data row22 col0" >Log Experiment</td>
#       <td id="T_fc12b_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fc12b_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_fc12b_row23_col0" class="data row23 col0" >Experiment Name</td>
#       <td id="T_fc12b_row23_col1" class="data row23 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_fc12b_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_fc12b_row24_col0" class="data row24 col0" >USI</td>
#       <td id="T_fc12b_row24_col1" class="data row24 col1" >d568</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model = create_model('lightgbm')
# Out:
# <style type="text/css">
# #T_7ca26_row10_col0, #T_7ca26_row10_col1, #T_7ca26_row10_col2, #T_7ca26_row10_col3, #T_7ca26_row10_col4, #T_7ca26_row10_col5, #T_7ca26_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_7ca26">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7ca26_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_7ca26_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_7ca26_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_7ca26_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_7ca26_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_7ca26_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_7ca26_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ca26_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7ca26_row0_col0" class="data row0 col0" >0.5671</td>
#       <td id="T_7ca26_row0_col1" class="data row0 col1" >0.7215</td>
#       <td id="T_7ca26_row0_col2" class="data row0 col2" >0.5671</td>
#       <td id="T_7ca26_row0_col3" class="data row0 col3" >0.6494</td>
#       <td id="T_7ca26_row0_col4" class="data row0 col4" >0.5170</td>
#       <td id="T_7ca26_row0_col5" class="data row0 col5" >0.1905</td>
#       <td id="T_7ca26_row0_col6" class="data row0 col6" >0.2572</td>
#     </tr>
#     <tr>
#       <th id="T_7ca26_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7ca26_row1_col0" class="data row1 col0" >0.7547</td>
#       <td id="T_7ca26_row1_col1" class="data row1 col1" >0.8459</td>
#       <td id="T_7ca26_row1_col2" class="data row1 col2" >0.7547</td>
#       <td id="T_7ca26_row1_col3" class="data row1 col3" >0.7402</td>
#       <td id="T_7ca26_row1_col4" class="data row1 col4" >0.7466</td>
#       <td id="T_7ca26_row1_col5" class="data row1 col5" >0.5155</td>
#       <td id="T_7ca26_row1_col6" class="data row1 col6" >0.5171</td>
#     </tr>
#     <tr>
#       <th id="T_7ca26_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7ca26_row2_col0" class="data row2 col0" >0.6832</td>
#       <td id="T_7ca26_row2_col1" class="data row2 col1" >0.8132</td>
#       <td id="T_7ca26_row2_col2" class="data row2 col2" >0.6832</td>
#       <td id="T_7ca26_row2_col3" class="data row2 col3" >0.6879</td>
#       <td id="T_7ca26_row2_col4" class="data row2 col4" >0.6661</td>
#       <td id="T_7ca26_row2_col5" class="data row2 col5" >0.4151</td>
#       <td id="T_7ca26_row2_col6" class="data row2 col6" >0.4400</td>
#     </tr>
#     <tr>
#       <th id="T_7ca26_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7ca26_row3_col0" class="data row3 col0" >0.6731</td>
#       <td id="T_7ca26_row3_col1" class="data row3 col1" >0.7740</td>
#       <td id="T_7ca26_row3_col2" class="data row3 col2" >0.6731</td>
#       <td id="T_7ca26_row3_col3" class="data row3 col3" >0.6526</td>
#       <td id="T_7ca26_row3_col4" class="data row3 col4" >0.6578</td>
#       <td id="T_7ca26_row3_col5" class="data row3 col5" >0.3780</td>
#       <td id="T_7ca26_row3_col6" class="data row3 col6" >0.3849</td>
#     </tr>
#     <tr>
#       <th id="T_7ca26_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7ca26_row4_col0" class="data row4 col0" >0.6650</td>
#       <td id="T_7ca26_row4_col1" class="data row4 col1" >0.7483</td>
#       <td id="T_7ca26_row4_col2" class="data row4 col2" >0.6650</td>
#       <td id="T_7ca26_row4_col3" class="data row4 col3" >0.6627</td>
#       <td id="T_7ca26_row4_col4" class="data row4 col4" >0.6447</td>
#       <td id="T_7ca26_row4_col5" class="data row4 col5" >0.3448</td>
#       <td id="T_7ca26_row4_col6" class="data row4 col6" >0.3480</td>
#     </tr>
#     <tr>
#       <th id="T_7ca26_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7ca26_row5_col0" class="data row5 col0" >0.6844</td>
#       <td id="T_7ca26_row5_col1" class="data row5 col1" >0.7752</td>
#       <td id="T_7ca26_row5_col2" class="data row5 col2" >0.6844</td>
#       <td id="T_7ca26_row5_col3" class="data row5 col3" >0.6910</td>
#       <td id="T_7ca26_row5_col4" class="data row5 col4" >0.6469</td>
#       <td id="T_7ca26_row5_col5" class="data row5 col5" >0.3351</td>
#       <td id="T_7ca26_row5_col6" class="data row5 col6" >0.3849</td>
#     </tr>
#     <tr>
#       <th id="T_7ca26_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7ca26_row6_col0" class="data row6 col0" >0.7070</td>
#       <td id="T_7ca26_row6_col1" class="data row6 col1" >0.8091</td>
#       <td id="T_7ca26_row6_col2" class="data row6 col2" >0.7070</td>
#       <td id="T_7ca26_row6_col3" class="data row6 col3" >0.6723</td>
#       <td id="T_7ca26_row6_col4" class="data row6 col4" >0.6868</td>
#       <td id="T_7ca26_row6_col5" class="data row6 col5" >0.4467</td>
#       <td id="T_7ca26_row6_col6" class="data row6 col6" >0.4521</td>
#     </tr>
#     <tr>
#       <th id="T_7ca26_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7ca26_row7_col0" class="data row7 col0" >0.7704</td>
#       <td id="T_7ca26_row7_col1" class="data row7 col1" >0.8587</td>
#       <td id="T_7ca26_row7_col2" class="data row7 col2" >0.7704</td>
#       <td id="T_7ca26_row7_col3" class="data row7 col3" >0.7382</td>
#       <td id="T_7ca26_row7_col4" class="data row7 col4" >0.7530</td>
#       <td id="T_7ca26_row7_col5" class="data row7 col5" >0.4783</td>
#       <td id="T_7ca26_row7_col6" class="data row7 col6" >0.4825</td>
#     </tr>
#     <tr>
#       <th id="T_7ca26_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7ca26_row8_col0" class="data row8 col0" >0.7428</td>
#       <td id="T_7ca26_row8_col1" class="data row8 col1" >0.8141</td>
#       <td id="T_7ca26_row8_col2" class="data row8 col2" >0.7428</td>
#       <td id="T_7ca26_row8_col3" class="data row8 col3" >0.7109</td>
#       <td id="T_7ca26_row8_col4" class="data row8 col4" >0.7240</td>
#       <td id="T_7ca26_row8_col5" class="data row8 col5" >0.3955</td>
#       <td id="T_7ca26_row8_col6" class="data row8 col6" >0.3983</td>
#     </tr>
#     <tr>
#       <th id="T_7ca26_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7ca26_row9_col0" class="data row9 col0" >0.6474</td>
#       <td id="T_7ca26_row9_col1" class="data row9 col1" >0.7907</td>
#       <td id="T_7ca26_row9_col2" class="data row9 col2" >0.6474</td>
#       <td id="T_7ca26_row9_col3" class="data row9 col3" >0.6543</td>
#       <td id="T_7ca26_row9_col4" class="data row9 col4" >0.6200</td>
#       <td id="T_7ca26_row9_col5" class="data row9 col5" >0.3253</td>
#       <td id="T_7ca26_row9_col6" class="data row9 col6" >0.3558</td>
#     </tr>
#     <tr>
#       <th id="T_7ca26_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_7ca26_row10_col0" class="data row10 col0" >0.6895</td>
#       <td id="T_7ca26_row10_col1" class="data row10 col1" >0.7951</td>
#       <td id="T_7ca26_row10_col2" class="data row10 col2" >0.6895</td>
#       <td id="T_7ca26_row10_col3" class="data row10 col3" >0.6860</td>
#       <td id="T_7ca26_row10_col4" class="data row10 col4" >0.6663</td>
#       <td id="T_7ca26_row10_col5" class="data row10 col5" >0.3825</td>
#       <td id="T_7ca26_row10_col6" class="data row10 col6" >0.4021</td>
#     </tr>
#     <tr>
#       <th id="T_7ca26_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_7ca26_row11_col0" class="data row11 col0" >0.0562</td>
#       <td id="T_7ca26_row11_col1" class="data row11 col1" >0.0400</td>
#       <td id="T_7ca26_row11_col2" class="data row11 col2" >0.0562</td>
#       <td id="T_7ca26_row11_col3" class="data row11 col3" >0.0324</td>
#       <td id="T_7ca26_row11_col4

# %%
tuned_model = tune_model(
    estimator=best_model,
    optimize="F1",
    early_stopping=True
)
# Out:
# <style type="text/css">
# #T_31f89_row10_col0, #T_31f89_row10_col1, #T_31f89_row10_col2, #T_31f89_row10_col3, #T_31f89_row10_col4, #T_31f89_row10_col5, #T_31f89_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_31f89">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_31f89_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_31f89_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_31f89_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_31f89_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_31f89_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_31f89_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_31f89_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_31f89_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_31f89_row0_col0" class="data row0 col0" >0.7102</td>
#       <td id="T_31f89_row0_col1" class="data row0 col1" >0.7841</td>
#       <td id="T_31f89_row0_col2" class="data row0 col2" >0.7102</td>
#       <td id="T_31f89_row0_col3" class="data row0 col3" >0.6895</td>
#       <td id="T_31f89_row0_col4" class="data row0 col4" >0.6992</td>
#       <td id="T_31f89_row0_col5" class="data row0 col5" >0.4324</td>
#       <td id="T_31f89_row0_col6" class="data row0 col6" >0.4338</td>
#     </tr>
#     <tr>
#       <th id="T_31f89_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_31f89_row1_col0" class="data row1 col0" >0.7597</td>
#       <td id="T_31f89_row1_col1" class="data row1 col1" >0.8410</td>
#       <td id="T_31f89_row1_col2" class="data row1 col2" >0.7597</td>
#       <td id="T_31f89_row1_col3" class="data row1 col3" >0.7448</td>
#       <td id="T_31f89_row1_col4" class="data row1 col4" >0.7519</td>
#       <td id="T_31f89_row1_col5" class="data row1 col5" >0.5262</td>
#       <td id="T_31f89_row1_col6" class="data row1 col6" >0.5270</td>
#     </tr>
#     <tr>
#       <th id="T_31f89_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_31f89_row2_col0" class="data row2 col0" >0.7447</td>
#       <td id="T_31f89_row2_col1" class="data row2 col1" >0.8190</td>
#       <td id="T_31f89_row2_col2" class="data row2 col2" >0.7447</td>
#       <td id="T_31f89_row2_col3" class="data row2 col3" >0.7032</td>
#       <td id="T_31f89_row2_col4" class="data row2 col4" >0.7234</td>
#       <td id="T_31f89_row2_col5" class="data row2 col5" >0.5004</td>
#       <td id="T_31f89_row2_col6" class="data row2 col6" >0.5034</td>
#     </tr>
#     <tr>
#       <th id="T_31f89_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_31f89_row3_col0" class="data row3 col0" >0.6964</td>
#       <td id="T_31f89_row3_col1" class="data row3 col1" >0.7725</td>
#       <td id="T_31f89_row3_col2" class="data row3 col2" >0.6964</td>
#       <td id="T_31f89_row3_col3" class="data row3 col3" >0.6536</td>
#       <td id="T_31f89_row3_col4" class="data row3 col4" >0.6743</td>
#       <td id="T_31f89_row3_col5" class="data row3 col5" >0.3985</td>
#       <td id="T_31f89_row3_col6" class="data row3 col6" >0.4015</td>
#     </tr>
#     <tr>
#       <th id="T_31f89_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_31f89_row4_col0" class="data row4 col0" >0.6945</td>
#       <td id="T_31f89_row4_col1" class="data row4 col1" >0.7863</td>
#       <td id="T_31f89_row4_col2" class="data row4 col2" >0.6945</td>
#       <td id="T_31f89_row4_col3" class="data row4 col3" >0.6525</td>
#       <td id="T_31f89_row4_col4" class="data row4 col4" >0.6728</td>
#       <td id="T_31f89_row4_col5" class="data row4 col5" >0.4055</td>
#       <td id="T_31f89_row4_col6" class="data row4 col6" >0.4084</td>
#     </tr>
#     <tr>
#       <th id="T_31f89_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_31f89_row5_col0" class="data row5 col0" >0.7108</td>
#       <td id="T_31f89_row5_col1" class="data row5 col1" >0.7907</td>
#       <td id="T_31f89_row5_col2" class="data row5 col2" >0.7108</td>
#       <td id="T_31f89_row5_col3" class="data row5 col3" >0.6864</td>
#       <td id="T_31f89_row5_col4" class="data row5 col4" >0.6980</td>
#       <td id="T_31f89_row5_col5" class="data row5 col5" >0.4332</td>
#       <td id="T_31f89_row5_col6" class="data row5 col6" >0.4346</td>
#     </tr>
#     <tr>
#       <th id="T_31f89_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_31f89_row6_col0" class="data row6 col0" >0.7177</td>
#       <td id="T_31f89_row6_col1" class="data row6 col1" >0.8126</td>
#       <td id="T_31f89_row6_col2" class="data row6 col2" >0.7177</td>
#       <td id="T_31f89_row6_col3" class="data row6 col3" >0.6777</td>
#       <td id="T_31f89_row6_col4" class="data row6 col4" >0.6969</td>
#       <td id="T_31f89_row6_col5" class="data row6 col5" >0.4646</td>
#       <td id="T_31f89_row6_col6" class="data row6 col6" >0.4676</td>
#     </tr>
#     <tr>
#       <th id="T_31f89_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_31f89_row7_col0" class="data row7 col0" >0.7886</td>
#       <td id="T_31f89_row7_col1" class="data row7 col1" >0.8687</td>
#       <td id="T_31f89_row7_col2" class="data row7 col2" >0.7886</td>
#       <td id="T_31f89_row7_col3" class="data row7 col3" >0.7574</td>
#       <td id="T_31f89_row7_col4" class="data row7 col4" >0.7725</td>
#       <td id="T_31f89_row7_col5" class="data row7 col5" >0.5266</td>
#       <td id="T_31f89_row7_col6" class="data row7 col6" >0.5291</td>
#     </tr>
#     <tr>
#       <th id="T_31f89_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_31f89_row8_col0" class="data row8 col0" >0.7622</td>
#       <td id="T_31f89_row8_col1" class="data row8 col1" >0.8229</td>
#       <td id="T_31f89_row8_col2" class="data row8 col2" >0.7622</td>
#       <td id="T_31f89_row8_col3" class="data row8 col3" >0.7102</td>
#       <td id="T_31f89_row8_col4" class="data row8 col4" >0.7337</td>
#       <td id="T_31f89_row8_col5" class="data row8 col5" >0.4083</td>
#       <td id="T_31f89_row8_col6" class="data row8 col6" >0.4182</td>
#     </tr>
#     <tr>
#       <th id="T_31f89_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_31f89_row9_col0" class="data row9 col0" >0.6675</td>
#       <td id="T_31f89_row9_col1" class="data row9 col1" >0.7932</td>
#       <td id="T_31f89_row9_col2" class="data row9 col2" >0.6675</td>
#       <td id="T_31f89_row9_col3" class="data row9 col3" >0.6312</td>
#       <td id="T_31f89_row9_col4" class="data row9 col4" >0.6448</td>
#       <td id="T_31f89_row9_col5" class="data row9 col5" >0.3642</td>
#       <td id="T_31f89_row9_col6" class="data row9 col6" >0.3716</td>
#     </tr>
#     <tr>
#       <th id="T_31f89_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_31f89_row10_col0" class="data row10 col0" >0.7252</td>
#       <td id="T_31f89_row10_col1" class="data row10 col1" >0.8091</td>
#       <td id="T_31f89_row10_col2" class="data row10 col2" >0.7252</td>
#       <td id="T_31f89_row10_col3" class="data row10 col3" >0.6906</td>
#       <td id="T_31f89_row10_col4" class="data row10 col4" >0.7068</td>
#       <td id="T_31f89_row10_col5" class="data row10 col5" >0.4460</td>
#       <td id="T_31f89_row10_col6" class="data row10 col6" >0.4495</td>
#     </tr>
#     <tr>
#       <th id="T_31f89_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_31f89_row11_col0" class="data row11 col0" >0.0354</td>
#       <td id="T_31f89_row11_col1" class="data row11 col1" >0.0282</td>
#       <td id="T_31f89_row11_col2" class="data row11 col2" >0.0354</td>
#       <td id="T_31f89_row11_col3" class="data row11 col3" >0.0381</td>
#       <td id="T_31f89_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
f = finalize_model(tuned_model)

# %%
plot_model(f,plot='confusion_matrix')

# %%
predictions = predict_model(f, data=test_data)
accuracy = accuracy_score(predictions['target_direction'], predictions['prediction_label'])
print("Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# <style type="text/css">
# </style>
# <table id="T_533ab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_533ab_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_533ab_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_533ab_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_533ab_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_533ab_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_533ab_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_533ab_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_533ab_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_533ab_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_533ab_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_533ab_row0_col1" class="data row0 col1" >0.8271</td>
#       <td id="T_533ab_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_533ab_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_533ab_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_533ab_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_533ab_row0_col6" class="data row0 col6" >0.3652</td>
#       <td id="T_533ab_row0_col7" class="data row0 col7" >0.3882</td>
#     </tr>
#   </tbody>
# </table>
# Accuracy: 82.71%

# %%
plot_model(f)

# %%
plot_model(f,plot="pr")

# %%
plot_model(f,plot="confusion_matrix")

# %%
plot_model(tuned_model,plot="learning",use_train_data=False)

# %%
plot_model(f,plot="feature",use_train_data=False)

# %%
plot_model(f,plot="boundary",use_train_data=False)

# %%
def yuzdeler(model, df, prediction_label, y):
    preds = predict_model(model, df)[[y, 'prediction_label', 'prediction_score']]
    son = pd.DataFrame()
    preds = preds[preds['prediction_label']==prediction_label]
    arange = np.arange(0.5, 1, 0.005)
    for i in arange:
        deneme = preds[preds['prediction_score']>=i]
        yuzde = round(accuracy_score(deneme[y], deneme['prediction_label']), 3)
        dicto = {'Thresh': i, 'Yüzde': yuzde, 'Len': len(deneme)}
        son = son.append(pd.DataFrame(dicto, index=[0]), ignore_index=True)
        son = son.dropna(axis=0)
    #son.to_csv(f"precs/{y}model_{prediction_label}.csv", index=False)
    return son.sort_values('Thresh', ascending=False)

# %%
predict_model(f, test_data)[["target_direction", 'prediction_label', 'prediction_score']]
# Out:
# <style type="text/css">
# </style>
# <table id="T_36b73">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_36b73_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_36b73_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_36b73_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_36b73_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_36b73_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_36b73_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_36b73_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_36b73_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_36b73_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_36b73_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_36b73_row0_col1" class="data row0 col1" >0.8271</td>
#       <td id="T_36b73_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_36b73_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_36b73_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_36b73_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_36b73_row0_col6" class="data row0 col6" >0.3652</td>
#       <td id="T_36b73_row0_col7" class="data row0 col7" >0.3882</td>
#     </tr>
#   </tbody>
# </table>
#       target_direction prediction_label  prediction_score
# 34943   ENERGY_SURPLUS   ENERGY_SURPLUS            0.5317
# 34944   ENERGY_SURPLUS   ENERGY_DEFICIT            0.5979
# 34945   ENERGY_SURPLUS   ENERGY_DEFICIT            0.6432
# 34946   ENERGY_SURPLUS   ENERGY_DEFICIT            0.5091
# 34947   ENERGY_SURPLUS   ENERGY_DEFICIT            0.5476
# ...                ...              ...               ...
# 43695   ENERGY_DEFICIT   ENERGY_DEFICIT            0.7975
# 43696   ENERGY_DEFICIT   ENERGY_DEFICIT            0.6981
# 43697   ENERGY_SURPLUS   ENERGY_DEFICIT            0.8171
# 43698   ENERGY_SURPLUS   ENERGY_DEFICIT            0.8070
# 43699   ENERGY_SURPLUS   ENERGY_DEFICIT            0.6138
#
# [8757 rows x 3 columns]

# %%
test_data['target_direction'].unique()
# Out:
# array(['ENERGY_SURPLUS', 'IN_BALANCE', 'ENERGY_DEFICIT'], dtype=object)

# %%
p = predict_model(f,data =test_data)

px =p[["date","target_direction",'prediction_label','prediction_score']]
# Out:
# <style type="text/css">
# </style>
# <table id="T_a57e5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a57e5_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a57e5_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_a57e5_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_a57e5_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_a57e5_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_a57e5_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_a57e5_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_a57e5_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a57e5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a57e5_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_a57e5_row0_col1" class="data row0 col1" >0.8271</td>
#       <td id="T_a57e5_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_a57e5_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a57e5_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_a57e5_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_a57e5_row0_col6" class="data row0 col6" >0.3652</td>
#       <td id="T_a57e5_row0_col7" class="data row0 col7" >0.3882</td>
#     </tr>
#   </tbody>
# </table>

# %%
px[(px['prediction_label']=='ENERGY_SURPLUS') & (px['prediction_score']>0.75)]
# Out:
#                             date target_direction prediction_label  \
# 37160  2022-04-03 09:00:00+03:00   ENERGY_SURPLUS   ENERGY_SURPLUS
# 37833  2022-05-01 10:00:00+03:00   ENERGY_SURPLUS   ENERGY_SURPLUS
# 37850  2022-05-02 03:00:00+03:00   ENERGY_SURPLUS   ENERGY_SURPLUS
# 37866  2022-05-02 19:00:00+03:00   ENERGY_DEFICIT   ENERGY_SURPLUS
# 37920  2022-05-05 01:00:00+03:00   ENERGY_SURPLUS   ENERGY_SURPLUS
# 37921  2022-05-05 02:00:00+03:00   ENERGY_SURPLUS   ENERGY_SURPLUS
# 37922  2022-05-05 03:00:00+03:00   ENERGY_SURPLUS   ENERGY_SURPLUS
# 37923  2022-05-05 04:00:00+03:00   ENERGY_SURPLUS   ENERGY_SURPLUS
# 38183  2022-05-16 00:00:00+03:00   ENERGY_SURPLUS   ENERGY_SURPLUS
# 38184  2022-05-16 01:00:00+03:00   ENERGY_SURPLUS   ENERGY_SURPLUS
# 39578  2022-07-13 03:00:00+03:00   ENERGY_SURPLUS   ENERGY_SURPLUS
# 39579  2022-07-13 04:00:00+03:00   ENERGY_SURPLUS   ENERGY_SURPLUS
#
#        prediction_score
# 37160            0.7662
# 37833            0.7567
# 37850            0.7675
# 37866            0.7687
# 37920            0.7770
# 37921            0.7812
# 37922            0.7878
# 37923            0.7688
# 38183            0.7741
# 38184            0.7525
# 39578            0.7702
# 39579            0.7596

# %%
yuzdeler(f,test_data,"ENERGY_SURPLUS","target_direction").head(50)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e3b97">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3b97_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e3b97_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_e3b97_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_e3b97_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_e3b97_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_e3b97_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_e3b97_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_e3b97_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3b97_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e3b97_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_e3b97_row0_col1" class="data row0 col1" >0.8271</td>
#       <td id="T_e3b97_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_e3b97_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_e3b97_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_e3b97_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_e3b97_row0_col6" class="data row0 col6" >0.3652</td>
#       <td id="T_e3b97_row0_col7" class="data row0 col7" >0.3882</td>
#     </tr>
#   </tbody>
# </table>
#     Thresh  Yüzde  Len
# 57   0.785  1.000    1
# 56   0.780  1.000    2
# 55   0.775  1.000    3
# 54   0.770  1.000    5
# 53   0.765  0.889    9
# 52   0.760  0.889    9
# 51   0.755  0.909   11
# 50   0.750  0.917   12
# 49   0.745  0.889   18
# 48   0.740  0.879   33
# 47   0.735  0.889   36
# 46   0.730  0.881   42
# 45   0.725  0.863   51
# 44   0.720  0.870   54
# 43   0.715  0.869   61
# 42   0.710  0.884   69
# 41   0.705  0.893   75
# 40   0.700  0.886   79
# 39   0.695  0.874   87
# 38   0.690  0.865   96
# 37   0.685  0.860  107
# 36   0.680  0.850  113
# 35   0.675  0.858  120
# 34   0.670  0.843  127
# 33   0.665  0.846  136
# 32   0.660  0.818  154
# 31   0.655  0.825  166
# 30   0.650  0.828  174
# 29   0.645  0.829  187
# 28   0.640  0.823  209
# 27   0.635  0.826  219
# 26   0.630  0.815  238
# 25   0.625  0.816  250
# 24   0.620  0.812  271
# 23   0.615  0.807  285
# 22   0.610  0.805  303
# 21   0.605  0.802  318
# 20   0.600  0.798  336
# 19   0.595  0.788  354
# 18   0.590  0.782  367
# 17   0.585  0.785  381
# 16   0.580  0.778  401
# 15   0.575  0.764  428
# 14   0.570  0.755  440
# 13   0.565  0.746  464
# 12   0.560  0.730  492
# 11   0.555  0.720  511
# 10   0.550  0.706  547
# 9    0.545  0.695  587
# 8    0.540  0.683  618

# %% [markdown]
# ### 1 Sınıfı İçin

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sonuclar = yuzdeler(f,test_data,"ENERGY_SURPLUS","target_direction").head(50)


# Doğruluk oranı (Yüzde) ve Eşik (Thresh) değerlerine göre bir çizgi grafiği oluşturma
plt.figure(figsize=(10, 5))
sns.lineplot(x='Thresh', y='Yüzde', data=sonuclar)
plt.title("Doğruluk Oranı vs Eşik Değeri")
plt.xlabel("Eşik Değeri")
plt.ylabel("Doğruluk Oranı")
plt.show()

# Doğruluk oranı (Yüzde) ve Örnek Sayısı (Len) arasındaki ilişkiyi gösteren bir dağılım grafiği oluşturma
plt.figure(figsize=(10, 5))
sns.scatterplot(x='Len', y='Yüzde', data=sonuclar)
plt.title("Doğruluk Oranı vs Örnek Sayısı")
plt.xlabel("Örnek Sayısı")
plt.ylabel("Doğruluk Oranı")
plt.show()

# Doğruluk oranı (Yüzde), Eşik (Thresh) değeri ve Örnek Sayısı (Len) arasındaki 3D ilişkiyi gösteren bir görsel
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

x = sonuclar['Thresh']
y = sonuclar['Yüzde']
z = sonuclar['Len']

ax.scatter(x, y, z, c='r', marker='o')

ax.set_xlabel("Eşik Değeri")
ax.set_ylabel("Doğruluk Oranı")
ax.set_zlabel("Örnek Sayısı")
plt.title("Doğruluk Oranı, Eşik Değeri ve Örnek Sayısı Arasındaki İlişki")
plt.show()


import plotly.express as px

fig = px.scatter_3d(sonuclar, x='Thresh', y='Yüzde', z='Len', color='Thresh',
                    labels={'Thresh': 'Eşik Değeri', 'Yüzde': 'Doğruluk Oranı', 'Len': 'Örnek Sayısı'},
                    title="Doğruluk Oranı, Eşik Değeri ve Örnek Sayısı Arasındaki İlişki")

fig.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_a2d05">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a2d05_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a2d05_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_a2d05_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_a2d05_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_a2d05_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_a2d05_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_a2d05_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_a2d05_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2d05_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a2d05_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_a2d05_row0_col1" class="data row0 col1" >0.8271</td>
#       <td id="T_a2d05_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_a2d05_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a2d05_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_a2d05_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_a2d05_row0_col6" class="data row0 col6" >0.3652</td>
#       <td id="T_a2d05_row0_col7" class="data row0 col7" >0.3882</td>
#     </tr>
#   </tbody>
# </table>
# <div>                            <div id="c00256fc-4c0e-4a02-a116-e7087cd21e46" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c00256fc-4c0e-4a02-a116-e7087cd21e46")) {                    Plotly.newPlot(                        "c00256fc-4c0e-4a02-a116-e7087cd21e46",                        [{"hovertemplate":"Eşik Değeri=%{marker.color}<br>Doğruluk Oranı=%{y}<br>Örnek Sayısı=%{z}<extra></extra>","legendgroup":"","marker":{"color":[0.7850000000000003,0.7800000000000002,0.7750000000000002,0.7700000000000002,0.7650000000000002,0.7600000000000002,0.7550000000000002,0.7500000000000002,0.7450000000000002,0.7400000000000002,0.7350000000000002,0.7300000000000002,0.7250000000000002,0.7200000000000002,0.7150000000000002,0.7100000000000002,0.7050000000000002,0.7000000000000002,0.6950000000000002,0.6900000000000002,0.6850000000000002,0.6800000000000002,0.6750000000000002,0.6700000000000002,0.6650000000000001,0.6600000000000001,0.6550000000000001,0.6500000000000001,0.6450000000000001,0.6400000000000001,0.6350000000000001,0.6300000000000001,0.6250000000000001,0.6200000000000001,0.6150000000000001,0.6100000000000001,0.6050000000000001,0.6000000000000001,0.5950000000000001,0.5900000000000001,0.5850000000000001,0.5800000000000001,0.5750000000000001,0.5700000000000001,0.5650000000000001,0.56,0.555,0.55,0.545,0.54],"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[0.7850000000000003,0.7800000000000002,0.7750000000000002,0.7700000000000002,0.7650000000000002,0.7600000000000002,0.7550000000000002,0.7500000000000002,0.7450000000000002,0.7400000000000002,0.7350000000000002,0.7300000000000002,0.7250000000000002,0.7200000000000002,0.7150000000000002,0.7100000000000002,0.7050000000000002,0.7000000000000002,0.6950000000000002,0.6900000000000002,0.6850000000000002,0.6800000000000002,0.6750000000000002,0.6700000000000002,0.6650000000000001,0.6600000000000001,0.6550000000000001,0.6500000000000001,0.6450000000000001,0.6400000000000001,0.6350000000000001,0.6300000000000001,0.6250000000000001,0.6200000000000001,0.6150000000000001,0.6100000000000001,0.6050000000000001,0.6000000000000001,0.5950000000000001,0.5900000000000001,0.5850000000000001,0.5800000000000001,0.5750000000000001,0.5700000000000001,0.5650000000000001,0.56,0.555,0.55,0.545,0.54],"y":[1.0,1.0,1.0,1.0,0.889,0.889,0.909,0.917,0.889,0.879,0.889,0.881,0.863,0.87,0.869,0.884,0.893,0.886,0.874,0.865,0.86,0.85,0.858,0.843,0.846,0.818,0.825,0.828,0.829,0.823,0.826,0.815,0.816,0.812,0.807,0.805,0.802,0.798,0.788,0.782,0.785,0.778,0.764,0.755,0.746,0.73,0.72,0.706,0.695,0.683],"z":[1,2,3,5,9,9,11,12,18,33,36,42,51,54,61,69,75,79,87,96,107,113,120,127,136,154,166,174,187,209,219,238,250,271,285,303,318,336,354,367,381,401,428,440,464,492,511,547,587,618],"type":"scatter3d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""}, ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sonuclar = yuzdeler(f,test_data,"ENERGY_DEFICIT","target_direction").head(50)


# Doğruluk oranı (Yüzde) ve Eşik (Thresh) değerlerine göre bir çizgi grafiği oluşturma
plt.figure(figsize=(10, 5))
sns.lineplot(x='Thresh', y='Yüzde', data=sonuclar)
plt.title("Doğruluk Oranı vs Eşik Değeri")
plt.xlabel("Eşik Değeri")
plt.ylabel("Doğruluk Oranı")
plt.show()

# Doğruluk oranı (Yüzde) ve Örnek Sayısı (Len) arasındaki ilişkiyi gösteren bir dağılım grafiği oluşturma
plt.figure(figsize=(10, 5))
sns.scatterplot(x='Len', y='Yüzde', data=sonuclar)
plt.title("Doğruluk Oranı vs Örnek Sayısı")
plt.xlabel("Örnek Sayısı")
plt.ylabel("Doğruluk Oranı")
plt.show()

# Doğruluk oranı (Yüzde), Eşik (Thresh) değeri ve Örnek Sayısı (Len) arasındaki 3D ilişkiyi gösteren bir görsel
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

x = sonuclar['Thresh']
y = sonuclar['Yüzde']
z = sonuclar['Len']

ax.scatter(x, y, z, c='r', marker='o')

ax.set_xlabel("Eşik Değeri")
ax.set_ylabel("Doğruluk Oranı")
ax.set_zlabel("Örnek Sayısı")
plt.title("Doğruluk Oranı, Eşik Değeri ve Örnek Sayısı Arasındaki İlişki")
plt.show()


import plotly.express as px

fig = px.scatter_3d(sonuclar, x='Thresh', y='Yüzde', z='Len', color='Thresh',
                    labels={'Thresh': 'Eşik Değeri', 'Yüzde': 'Doğruluk Oranı', 'Len': 'Örnek Sayısı'},
                    title="Doğruluk Oranı, Eşik Değeri ve Örnek Sayısı Arasındaki İlişki")

fig.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_f18bf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f18bf_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f18bf_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_f18bf_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_f18bf_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_f18bf_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_f18bf_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_f18bf_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_f18bf_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f18bf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f18bf_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_f18bf_row0_col1" class="data row0 col1" >0.8271</td>
#       <td id="T_f18bf_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_f18bf_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_f18bf_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_f18bf_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_f18bf_row0_col6" class="data row0 col6" >0.3652</td>
#       <td id="T_f18bf_row0_col7" class="data row0 col7" >0.3882</td>
#     </tr>
#   </tbody>
# </table>
# <div>                            <div id="2d56b8e0-8769-46eb-a97b-e5ae4c5b4622" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2d56b8e0-8769-46eb-a97b-e5ae4c5b4622")) {                    Plotly.newPlot(                        "2d56b8e0-8769-46eb-a97b-e5ae4c5b4622",                        [{"hovertemplate":"Eşik Değeri=%{marker.color}<br>Doğruluk Oranı=%{y}<br>Örnek Sayısı=%{z}<extra></extra>","legendgroup":"","marker":{"color":[0.8700000000000003,0.8650000000000003,0.8600000000000003,0.8550000000000003,0.8500000000000003,0.8450000000000003,0.8400000000000003,0.8350000000000003,0.8300000000000003,0.8250000000000003,0.8200000000000003,0.8150000000000003,0.8100000000000003,0.8050000000000003,0.8000000000000003,0.7950000000000003,0.7900000000000003,0.7850000000000003,0.7800000000000002,0.7750000000000002,0.7700000000000002,0.7650000000000002,0.7600000000000002,0.7550000000000002,0.7500000000000002,0.7450000000000002,0.7400000000000002,0.7350000000000002,0.7300000000000002,0.7250000000000002,0.7200000000000002,0.7150000000000002,0.7100000000000002,0.7050000000000002,0.7000000000000002,0.6950000000000002,0.6900000000000002,0.6850000000000002,0.6800000000000002,0.6750000000000002,0.6700000000000002,0.6650000000000001,0.6600000000000001,0.6550000000000001,0.6500000000000001,0.6450000000000001,0.6400000000000001,0.6350000000000001,0.6300000000000001,0.6250000000000001],"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[0.8700000000000003,0.8650000000000003,0.8600000000000003,0.8550000000000003,0.8500000000000003,0.8450000000000003,0.8400000000000003,0.8350000000000003,0.8300000000000003,0.8250000000000003,0.8200000000000003,0.8150000000000003,0.8100000000000003,0.8050000000000003,0.8000000000000003,0.7950000000000003,0.7900000000000003,0.7850000000000003,0.7800000000000002,0.7750000000000002,0.7700000000000002,0.7650000000000002,0.7600000000000002,0.7550000000000002,0.7500000000000002,0.7450000000000002,0.7400000000000002,0.7350000000000002,0.7300000000000002,0.7250000000000002,0.7200000000000002,0.7150000000000002,0.7100000000000002,0.7050000000000002,0.7000000000000002,0.6950000000000002,0.6900000000000002,0.6850000000000002,0.6800000000000002,0.6750000000000002,0.6700000000000002,0.6650000000000001,0.6600000000000001,0.6550000000000001,0.6500000000000001,0.6450000000000001,0.6400000000000001,0.6350000000000001,0.6300000000000001,0.6250000000000001],"y":[0.993,0.991,0.988,0.984,0.98,0.98,0.975,0.969,0.969,0.965,0.962,0.956,0.956,0.956,0.955,0.953,0.95,0.948,0.946,0.943,0.942,0.939,0.937,0.936,0.937,0.933,0.93,0.927,0.924,0.922,0.919,0.918,0.917,0.916,0.914,0.912,0.91,0.909,0.907,0.904,0.902,0.901,0.899,0.899,0.898,0.897,0.895,0.895,0.893,0.893],"z":[142,328,580,828,1063,1273,1460,1664,1845,2015,2168,2312,2442,2590,2734,2867,2995,3113,3226,3352,3474,3597,3721,3837,3957,4080,4232,4325,4433,4539,4642,4758,4867,4990,5105,5189,5289,5369,5444,5516,5572,5628,5693,5740,5788,5871,5936,6011,6075,6163],"type":"scatter3d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786 ...

# %%
save_model(f,'last_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=C:\Users\Hakan\AppData\Local\Temp\joblib),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['net', 'upRegulationZeroCoded',
#                                               'upRegulationOneCoded',
#                                               'downRegulationZeroCoded',
#                                               'downRegulationOneCod...
#                                  boosting_type='gbdt', class_weight=None,
#                                  colsample_bytree=1.0, feature_fraction=0.5,
#                                  importance_type='split', learning_rate=0.1,
#                                  max_depth=-1, min_child_samples=81,
#                                  min_child_weight=0.001, min_split_gain=0.4,
#                                  n_estimators=10, n_jobs=-1, num_leaves=200,
#                                  objective=None, random_state=1901,
#                                  reg_alpha=0.4, reg_lambda=1, silent='warn',
#                                  subsample=1.0, subsample_for_bin=200000,
#                                  subsample_freq=0))],
#           verbose=False),
#  'last_model.pkl')
